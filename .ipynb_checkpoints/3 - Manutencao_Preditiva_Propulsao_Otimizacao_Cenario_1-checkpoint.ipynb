# %% [markdown]
# # Manutenção Preditiva (PHM) - Sistema de Propulsão Naval
#
# Rafael Schena
#
# Edit: Alteração dos gatilhos de target para os estados de Emergência, Alerta e Normal, adicionando mais 2 cenários para as proporções de estados dos equipamentos: (10% Emerg, 10% Alert, 80% Normal) e (5% Emerg, 5% Alert e 90% Normal) para observação do desempenho dos algoritmos.

# %% [markdown]
# ## Metodologia
#
# Foi utilizada neste trabalho a metodologia CRISP-DM (CRoss-Industry Standard Process for Data Mining)
# ![crisp-dm](img/crisp-dm.png)
#
# Fases:
# 1. Business understanding – What does the business need?
# 2. Data understanding – What data do we have / need? Is it clean?
# 3. Data preparation – How do we organize the data for modeling?
# 4. Modeling – What modeling techniques should we apply?
# 5. Evaluation – Which model best meets the business objectives?
# 6. Deployment – How do stakeholders access the results?
#
# (https://www.datascience-pm.com/crisp-dm-2/)

# %% [markdown]
# ## 1 - Compreensão do problema de negócio (Business Understanding)
# Este trabalho tem como objetivo principal a mineração de padrões em dados de manutenção preditiva (PHM - Predictive Health Monitoring) em um sistema de propulsão naval. O dataset utilizado foi disponibilizado é um dataset simulado em um modelo de um sistema de propulsão naval de uma fragata que utiliza uma turbina a gás como motor. O dataset foi disponibilizado pelos autores (M Altosole, G Benvenuto, M Figari, and U Campora) no repositório da UCI: http://archive.ics.uci.edu/ml/datasets/condition+based+maintenance+of+naval+propulsion+plants

# %% [markdown]
# Fragata:
# ![fragata](img/frigate.png)

# %% [markdown]
# Sistema de propulsão:
# ![propulsao](img/propulsion.png)
# https://navalpost.com/propulsion-systems-navies-gas-diesel-electric/
#
# Turbina a Gás (Termo mais correto: motor a reação):
# ![turbina](img/gas_turbine.png)
# https://www.geaviation.com/sites/default/files/ge-marine-gas-turbines-for-frigates-2018-march.pdf
#
# ![mecanismo](img/turbine_mechanism.gif)

# %% [markdown]
# ## Definição do problema de negócio (!!!)
# O dataset não define o que caracteriza ou não uma falha no sistema de propulsão da fragata, apenas apresenta os índices de degradação dos estágios de compressão e da turbina. **Níveis de alerta de degradação serão definidos com base na distribuição dos índices de degradação do compressor (kMc) e da turbina (kMt).** Antes disso, será necessária uma melhor compreensão dos dados.
#
# Dicionário de dados:
# - 1 - Lever position (lp) [ ]
# - 2 - Ship speed (v) [knots]
# - 3 - Gas Turbine shaft torque (GTT) [kN m]
# - 4 - Gas Turbine rate of revolutions (GTn) [rpm]
# - 5 - Gas Generator rate of revolutions (GGn) [rpm]
# - 6 - Starboard Propeller Torque (Ts) [kN]
# - 7 - Port Propeller Torque (Tp) [kN]
# - 8 - HP Turbine exit temperature (T48) [C]
# - 9 - GT Compressor inlet air temperature (T1) [C]
# - 10 - GT Compressor outlet air temperature (T2) [C]
# - 11 - HP Turbine exit pressure (P48) [bar]
# - 12 - GT Compressor inlet air pressure (P1) [bar]
# - 13 - GT Compressor outlet air pressure (P2) [bar]
# - 14 - Gas Turbine exhaust gas pressure (Pexh) [bar]
# - 15 - Turbine Injecton Control (TIC) [%]
# - 16 - Fuel flow (mf) [kg/s]
# - 17 - GT Compressor decay state coefficient (kMc).
# - 18 - GT Turbine decay state coefficient (kMt).

# %% [markdown]
# ## 2 - Compreensão dos dados (Data Understanding)

# %%
import pandas as pd
import numpy as np

# %%
features = [
    'lp',
    'v',
    'GTT',
    'GTn',
    'GGn',
    'Ts',
    'Tp',
    'T48',
    'T1',
    'T2',
    'P48',
    'P1',
    'P2',
    'Pexh',
    'TIC',
    'mf',
    'kMc',
    'kMt'
]

# %%
df = pd.read_csv('./data/data.txt', sep='   ', names=features, engine='python')

# %%
df.head()
# Out:
#       lp     v        GTT       GTn       GGn       Ts       Tp      T48  \
# 0  1.138   3.0    289.964  1349.489  6677.380    7.584    7.584  464.006
# 1  2.088   6.0   6960.180  1376.166  6828.469   28.204   28.204  635.401
# 2  3.144   9.0   8379.229  1386.757  7111.811   60.358   60.358  606.002
# 3  4.161  12.0  14724.395  1547.465  7792.630  113.774  113.774  661.471
# 4  5.140  15.0  21636.432  1924.313  8494.777  175.306  175.306  731.494
#
#       T1       T2    P48     P1      P2   Pexh     TIC     mf   kMc    kMt
# 0  288.0  550.563  1.096  0.998   5.947  1.019   7.137  0.082  0.95  0.975
# 1  288.0  581.658  1.331  0.998   7.282  1.019  10.655  0.287  0.95  0.975
# 2  288.0  587.587  1.389  0.998   7.574  1.020  13.086  0.259  0.95  0.975
# 3  288.0  613.851  1.658  0.998   9.007  1.022  18.109  0.358  0.95  0.975
# 4  288.0  645.642  2.078  0.998  11.197  1.026  26.373  0.522  0.95  0.975

# %%
df.shape
# Out:
# (11934, 18)

# %% [markdown]
# ### Verificação valores faltantes e tipos de dados

# %%
# Não há valores faltantes, todas as variáveis são numéricas do tipo float64
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11934 entries, 0 to 11933
# Data columns (total 18 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   lp      11934 non-null  float64
#  1   v       11934 non-null  float64
#  2   GTT     11934 non-null  float64
#  3   GTn     11934 non-null  float64
#  4   GGn     11934 non-null  float64
#  5   Ts      11934 non-null  float64
#  6   Tp      11934 non-null  float64
#  7   T48     11934 non-null  float64
#  8   T1      11934 non-null  float64
#  9   T2      11934 non-null  float64
#  10  P48     11934 non-null  float64
#  11  P1      11934 non-null  float64
#  12  P2      11934 non-null  float64
#  13  Pexh    11934 non-null  float64
#  14  TIC     11934 non-null  float64
#  15  mf      11934 non-null  float64
#  16  kMc     11934 non-null  float64
#  17  kMt     11934 non-null  float64
# dtypes: float64(18)
# memory usage: 1.6 MB

# %% [markdown]
# ### Estatísticas das features numéricas

# %%
df.describe()
# Out:
#                  lp             v           GTT           GTn           GGn  \
# count  11934.000000  11934.000000  11934.000000  11934.000000  11934.000000
# mean       5.166667     15.000000  27247.498685   2136.289256   8200.947312
# std        2.626388      7.746291  22148.613155    774.083881   1091.315507
# min        1.138000      3.000000    253.547000   1307.675000   6589.002000
# 25%        3.144000      9.000000   8375.883750   1386.758000   7058.324000
# 50%        5.140000     15.000000  21630.659000   1924.326000   8482.081500
# 75%        7.148000     21.000000  39001.426750   2678.079000   9132.606000
# max        9.300000     27.000000  72784.872000   3560.741000   9797.103000
#
#                  Ts            Tp           T48       T1            T2  \
# count  11934.000000  11934.000000  11934.000000  11934.0  11934.000000
# mean     227.335768    227.335768    735.495446    288.0    646.215331
# std      200.495889    200.495889    173.680552      0.0     72.675882
# min        5.304000      5.304000    442.364000    288.0    540.442000
# 25%       60.317000     60.317000    589.872750    288.0    578.092250
# 50%      175.268000    175.268000    706.038000    288.0    637.141500
# 75%      332.364750    332.364750    834.066250    288.0    693.924500
# max      645.249000    645.249000   1115.797000    288.0    789.094000
#
#                 P48            P1            P2          Pexh           TIC  \
# count  11934.000000  1.193400e+04  11934.000000  11934.000000  11934.000000
# mean       2.352963  9.980000e-01     12.297123      1.029474     33.641261
# std        1.084770  2.533635e-13      5.337448      0.010390     25.841363
# min        1.093000  9.980000e-01      5.828000      1.019000      0.000000
# 25%        1.389000  9.980000e-01      7.447250      1.020000     13.677500
# 50%        2.083000  9.980000e-01     11.092000      1.026000     25.276500
# 75%        2.981000  9.980000e-01     15.658000      1.036000     44.552500
# max        4.560000  9.980000e-01     23.140000      1.052000     92.556000
#
#                  mf          kMc         kMt
# count  11934.000000  11934.00000  11934.0000
# mean       0.662440      0.97500      0.9875
# std        0.507132      0.01472      0.0075
# min        0.068000      0.95000      0.9750
# 25%        0.246000      0.96200      0.9810
# 50%        0.496000      0.97500      0.9875
# 75%        0.882000      0.98800      0.9940
# max        1.832000      1.00000      1.0000

# %%
for col in df.columns:
    print(f'Valores únicos de {col}: {len(df[col].unique())}')
# Out:
# Valores únicos de lp: 9
# Valores únicos de v: 9
# Valores únicos de GTT: 11430
# Valores únicos de GTn: 3888
# Valores únicos de GGn: 11834
# Valores únicos de Ts: 4286
# Valores únicos de Tp: 4286
# Valores únicos de T48: 11772
# Valores únicos de T1: 1
# Valores únicos de T2: 11506
# Valores únicos de P48: 524
# Valores únicos de P1: 1
# Valores únicos de P2: 4209
# Valores únicos de Pexh: 19
# Valores únicos de TIC: 8496
# Valores únicos de mf: 696
# Valores únicos de kMc: 51
# Valores únicos de kMt: 26

# %% [markdown]
# ### Verificando a presença de outliers nos dados

# %%
import matplotlib.pyplot as plt

# %%
fig, ax_matrix = plt.subplots(6, 3, figsize=(20, 20));

# Atribuir um subgráfico para cada feature
mapeamento = {}
for (i, f) in enumerate(features):
    mapeamento[f] = ax_matrix[i//3][i%3]

for feat in features:
    mapeamento[feat].set_title(f'Boxplot {feat}')
    mapeamento[feat].boxplot(df[feat])
    
plt.show()

# %% [markdown]
# ### Constatações:
# - As features T1 e P1 não apresentam variabilidade e podem ser eliminadas do dataset, porque não contribuem para a previsibilidade das variáveis target;
# - A feature TIC apresenta outliers que merecem ser investigados mais a fundo;

# %% [markdown]
# ## Verificação da distribuição dos dados

# %%
fig, ax_matrix = plt.subplots(6, 3, figsize=(20, 20));

# Atribuir um subgráfico para cada feature
mapeamento = {}
for (i, f) in enumerate(features):
    mapeamento[f] = ax_matrix[i//3][i%3]

for feat in features:
    mapeamento[feat].set_title(f'Histograma {feat}')
    mapeamento[feat].hist(df[feat], bins=30)
    
plt.show()

# %%
# Histogramas com maior número de bins

fig, ax_matrix = plt.subplots(6, 3, figsize=(20, 20));

# Atribuir um subgráfico para cada feature
mapeamento = {}
for (i, f) in enumerate(features):
    mapeamento[f] = ax_matrix[i//3][i%3]

for feat in features:
    mapeamento[feat].set_title(f'Histograma {feat}')
    mapeamento[feat].hist(df[feat], bins=100)
    
plt.show()

# %% [markdown]
# ### Cálculo dos erros
#
# Dalheim and Steen, 2021
# Dalheim Øyvind Øksnes, Steen Sverre
# Uncertainty in the real-time estimation of ship speed through water
# Ocean Engineering, 235 (2021), Article 109423
# https://www.sciencedirect.com/science/article/pii/S0029801821008313
#
# Erros de torque e rotação
# ![Erros_I](img/tabela_erro.png)
# - Torque: 0,25% Full Scale
# - Rotação: 0,25% Full Scale
#
# Erros de velocidade na água
# ![Erros_II](img/tabela_erro_II.png)
# - Velocidade: 1,95% a 3,6%
#
# Brun, K. and Kurz, R., 1903. MEASUREMENT UNCERTAINTIES ENCOUNTERED DURING 98-GT-1 GAS TURBINE DRIVEN COMPRESSOR FIELD TESTING.
# https://citeseerx.ist.psu.edu/viewdoc/download?doi=10.1.1.943.1621&rep=rep1&type=pdf
#
# Temperatura, pressão e fluxo:
# - Temperatura: 0,1ºC
# - Pressão: 1% Full Scale
# - Flow meter: 2% Full Scale

# %% [markdown]
# Erros de medição - estimativa de piores cenários:
# - 2 - Ship speed (v) [knots] - 3,6%
# - 3 - Gas Turbine shaft torque (GTT) [kN m] - 1%
# - 4 - Gas Turbine rate of revolutions (GTn) [rpm] - 1%
# - 5 - Gas Generator rate of revolutions (GGn) [rpm] - 1%
# - 6 - Starboard Propeller Torque (Ts) [kN] - 1%
# - 7 - Port Propeller Torque (Tp) [kN] - 1%
# - 8 - HP Turbine exit temperature (T48) [C] - 0,01%
# - 9 - GT Compressor inlet air temperature (T1) [C] - 0,01%
# - 10 - GT Compressor outlet air temperature (T2) [C] - 0,01%
# - 11 - HP Turbine exit pressure (P48) [bar] - 1%
# - 12 - GT Compressor inlet air pressure (P1) [bar] - 1%
# - 13 - GT Compressor outlet air pressure (P2) [bar] - 1%
# - 14 - Gas Turbine exhaust gas pressure (Pexh) [bar] - 1%
# - 16 - Fuel flow (mf) [kg/s] - 2%

# %%
variaveis = df.columns
variaveis
# Out:
# Index(['lp', 'v', 'GTT', 'GTn', 'GGn', 'Ts', 'Tp', 'T48', 'T1', 'T2', 'P48',
#        'P1', 'P2', 'Pexh', 'TIC', 'mf', 'kMc', 'kMt'],
#       dtype='object')

# %%
# Associação das grandezas com os erros estimados correspondentes:

erros = {'lp': 0, 
         'v': 0.036, 
         'GTT': 0.01, 
         'GTn': 0.01, 
         'GGn': 0.01, 
         'Ts': 0.01, 
         'Tp': 0.01, 
         'T48': 0.0001, 
         'T1': 0.0001, 
         'T2': 0.0001, 
         'P48': 0.01,
         'P1': 0.01, 
         'P2': 0.01, 
         'Pexh': 0.01, 
         'TIC': 0, 
         'mf': 0.02, 
         'kMc': 0, 
         'kMt': 0
}

# %%
# Inserindo erros no dataset
from random import gauss

#df_bkp = df.copy()

for key, value in erros.items():
    df[key] = df[key].map(lambda x:gauss(x, value*df[key].median()))

# %%
df['v'].max()
# Out:
# 28.701036297167917

# %%
df.head()
# Out:
#       lp          v           GTT          GTn          GGn          Ts  \
# 0  1.138   3.285108    355.331025  1307.353384  6523.884372    8.769179
# 1  2.088   4.932878   6508.994853  1394.558906  6836.383687   25.848960
# 2  3.144   9.256739   8586.669936  1377.919146  7081.543007   60.268974
# 3  4.161  11.455049  14737.377677  1549.917343  7852.449324  111.370792
# 4  5.140  15.457852  21570.033036  1939.042202  8561.228286  173.810801
#
#            Tp         T48          T1          T2       P48        P1  \
# 0    7.512436  464.033912  288.017293  550.587223  1.092193  0.992346
# 1   27.727411  635.495566  288.081955  581.626731  1.320198  0.999698
# 2   58.114345  605.926500  288.026262  587.555248  1.399310  0.993460
# 3  113.070700  661.529541  288.000376  613.900832  1.653586  0.979059
# 4  178.453651  731.478841  287.968341  645.722111  2.092302  1.008631
#
#           P2      Pexh     TIC        mf   kMc    kMt
# 0   6.025915  1.016685   7.137  0.076914  0.95  0.975
# 1   7.071318  1.033962  10.655  0.274434  0.95  0.975
# 2   7.551384  1.015596  13.086  0.243612  0.95  0.975
# 3   8.937318  1.010129  18.109  0.356415  0.95  0.975
# 4  11.170710  1.025160  26.373  0.524751  0.95  0.975

# %%
# Verificando resultados na distribuição dos dados

# Histogramas com maior número de bins

fig, ax_matrix = plt.subplots(6, 3, figsize=(20, 20));

# Atribuir um subgráfico para cada feature
mapeamento = {}
for (i, f) in enumerate(features):
    mapeamento[f] = ax_matrix[i//3][i%3]

for feat in features:
    mapeamento[feat].set_title(f'Histograma {feat}')
    mapeamento[feat].hist(df[feat], bins=100)
    
plt.show()

# %% [markdown]
# ### Constatações
# - Os dados não se apresentam na forma de séries temporais, uma vez que não têm associado um timestamp e nenhuma indicação de que estão em uma sequência no tempo;
# - Na distribuição estatística dos dados (histogramas) podem ser verificados muitos gaps, indicando que existem faixas de valores que não constam no conjunto de dados, apesar de se tratar de um dataset composto somente por variáveis contínuas. Tal característica da distribuição dos dados permite que se efetue uma discretização destas grandezas com uma menor perda de informação (erro de quantização). Isto sugere que pode ser interessante a criação de novas features a partir da discretização das features originais.
# - Faixas de variação muito diferentes entre as features;
# - Os outliers da feature TIC representam os valores acima de 80% da capacidade de injeção de combustível na turbina. Representam os casos em que a fragata demandou uma aceleração maior e somam cerca de 1200 observações no dataset (aproximadamente 10% das observações). Decidiu-se por manter estes valores por representarem situações de operação normal do equipamento.

# %% [markdown]
# ## (!!!) Definição do problema de negócio com base nos dados
# Para os targets kMc e kMt fica **arbitrariamente** definido:
#
# Cenário 0:
# - **Emergência**: faixa de 33% piores valores possíveis para o range observado;
# - **Alerta**: faixa entre 33% e 66% piores valores possíveis para o range observado;
# - **Normal**: faixa de 33% melhores valores possíveis para o range observado.
#
# Cenário 1:
# - **Emergência**: faixa de 10% piores valores possíveis para o range observado;
# - **Alerta**: faixa entre 10% e 20% piores valores possíveis para o range observado;
# - **Normal**: faixa de 80% melhores valores possíveis para o range observado.
#
# Cenário 2:
# - **Emergência**: faixa de 5% piores valores possíveis para o range observado;
# - **Alerta**: faixa entre 5% e 10% piores valores possíveis para o range observado;
# - **Normal**: faixa de 90% melhores valores possíveis para o range observado.

# %%
range_kMc = df['kMc'].max() - df['kMc'].min()

# %%
# Proporções percentuais para os cenários 0, 1 e 2, respectivamente, como tuplas na lista proporções
cenarios = [(0.33, 0.66),
             (0.1, 0.2),
             (0.05, 0.1)]

# %%
# Lista com os valores limites de kMc para alerta e emergência para os três cenários
lim_comp = []

for c in cenarios:
    lim = {}
    lim['emerg'] = df['kMc'].min() + c[0]*range_kMc
    lim['alert'] = df['kMc'].min() + c[1]*range_kMc
    lim_comp.append(lim)

# %%
for k in range(len(lim_comp)):
    print(f'Níveis de emergência e alerta de kMc para o cenário {k}: {lim_comp[k]}')
# Out:
# Níveis de emergência e alerta de kMc para o cenário 0: {'emerg': 0.9664999999999999, 'alert': 0.983}
# Níveis de emergência e alerta de kMc para o cenário 1: {'emerg': 0.955, 'alert': 0.96}
# Níveis de emergência e alerta de kMc para o cenário 2: {'emerg': 0.9524999999999999, 'alert': 0.955}

# %%
# Lista com os valores limites de kMc para alerta e emergência para os três cenários
range_kMt = df['kMt'].max() - df['kMt'].min()
lim_turb = []

for c in cenarios:
    lim = {}
    lim['emerg'] = df['kMt'].min() + c[0]*range_kMt
    lim['alert'] = df['kMt'].min() + c[1]*range_kMt
    lim_turb.append(lim)

# %%
for k in range(len(lim_turb)):
    print(f'Níveis de emergência e alerta de kMt para o cenário {k}: {lim_turb[k]}')
# Out:
# Níveis de emergência e alerta de kMt para o cenário 0: {'emerg': 0.98325, 'alert': 0.9915}
# Níveis de emergência e alerta de kMt para o cenário 1: {'emerg': 0.9775, 'alert': 0.98}
# Níveis de emergência e alerta de kMt para o cenário 2: {'emerg': 0.97625, 'alert': 0.9775}

# %%
for k in range(len(cenarios)):
    fig, ax = plt.subplots(1, 2, figsize=(16, 4))
    fig.suptitle(f'Cenário {k}')
    
    ax[0].set_title(f'Histograma kMc')
    ax[0].axvline(lim_comp[k]['alert'], color='orange', lw=2, alpha=1)
    ax[0].axvline(lim_comp[k]['emerg'], color='red', lw=2, alpha=1)
    ax[0].hist(df['kMc'], bins=30, alpha = 0.3);

    ax[1].set_title(f'Histograma kMt')
    ax[1].axvline(lim_turb[k]['alert'], color='orange', lw=2, alpha=1)
    ax[1].axvline(lim_turb[k]['emerg'], color='red', lw=2, alpha=1)
    ax[1].hist(df['kMt'], bins=30, alpha = 0.3);

# %% [markdown]
# ### Exclusão das features que não acrescentam informação ao dataset:

# %%
# Excluindo as features que não apresentam variabilidade
df.drop(columns=['T1', 'P1'], inplace=True)
features = df.columns
df.head()
# Out:
#       lp          v           GTT          GTn          GGn          Ts  \
# 0  1.138   3.285108    355.331025  1307.353384  6523.884372    8.769179
# 1  2.088   4.932878   6508.994853  1394.558906  6836.383687   25.848960
# 2  3.144   9.256739   8586.669936  1377.919146  7081.543007   60.268974
# 3  4.161  11.455049  14737.377677  1549.917343  7852.449324  111.370792
# 4  5.140  15.457852  21570.033036  1939.042202  8561.228286  173.810801
#
#            Tp         T48          T2       P48         P2      Pexh     TIC  \
# 0    7.512436  464.033912  550.587223  1.092193   6.025915  1.016685   7.137
# 1   27.727411  635.495566  581.626731  1.320198   7.071318  1.033962  10.655
# 2   58.114345  605.926500  587.555248  1.399310   7.551384  1.015596  13.086
# 3  113.070700  661.529541  613.900832  1.653586   8.937318  1.010129  18.109
# 4  178.453651  731.478841  645.722111  2.092302  11.170710  1.025160  26.373
#
#          mf   kMc    kMt
# 0  0.076914  0.95  0.975
# 1  0.274434  0.95  0.975
# 2  0.243612  0.95  0.975
# 3  0.356415  0.95  0.975
# 4  0.524751  0.95  0.975

# %%
type(lim_comp[k]['emerg'])
# Out:
# float

# %% [markdown]
# ### Criação dos labels das variáveis target

# %%
# status_c é o status do compressor, podendo assumir valores 'Emerg', 'Alert', 'Normal'
df['status_c_0'] = pd.cut(df['kMc'], bins=[0, lim_comp[0]['emerg'], lim_comp[0]['alert'], float('Inf')], labels=['Emerg', 'Alert', 'Normal'])
# status_t é o status do compressor, podendo assumir valores 'Emerg', 'Alert', 'Normal'
df['status_t_0'] = pd.cut(df['kMt'], bins=[0, lim_turb[0]['emerg'], lim_turb[0]['alert'], float('Inf')], labels=['Emerg', 'Alert', 'Normal'])

df['status_c_1'] = pd.cut(df['kMc'], bins=[0, lim_comp[1]['emerg'], lim_comp[1]['alert'], float('Inf')], labels=['Emerg', 'Alert', 'Normal'])
df['status_t_1'] = pd.cut(df['kMt'], bins=[0, lim_turb[1]['emerg'], lim_turb[1]['alert'], float('Inf')], labels=['Emerg', 'Alert', 'Normal'])

df['status_c_2'] = pd.cut(df['kMc'], bins=[0, lim_comp[2]['emerg'], lim_comp[2]['alert'], float('Inf')], labels=['Emerg', 'Alert', 'Normal'])
df['status_t_2'] = pd.cut(df['kMt'], bins=[0, lim_turb[2]['emerg'], lim_turb[2]['alert'], float('Inf')], labels=['Emerg', 'Alert', 'Normal'])

# %%
df
# Out:
#           lp          v           GTT          GTn          GGn          Ts  \
# 0      1.138   3.285108    355.331025  1307.353384  6523.884372    8.769179
# 1      2.088   4.932878   6508.994853  1394.558906  6836.383687   25.848960
# 2      3.144   9.256739   8586.669936  1377.919146  7081.543007   60.268974
# 3      4.161  11.455049  14737.377677  1549.917343  7852.449324  111.370792
# 4      5.140  15.457852  21570.033036  1939.042202  8561.228286  173.810801
# ...      ...        ...           ...          ...          ...         ...
# 11929  5.140  14.651664  21909.217094  1911.604470  8518.237680  175.628451
# 11930  6.175  18.499620  29731.940988  2321.029204  8861.118176  242.993486
# 11931  7.148  20.727082  39166.002585  2686.852984  9261.068704  332.394477
# 11932  8.206  24.557146  51148.243118  3099.907219  9408.364580  442.523179
# 11933  9.300  27.074587  72903.149154  3543.309629  9831.253053  641.241655
#
#                Tp          T48          T2       P48  ...     TIC        mf  \
# 0        7.512436   464.033912  550.587223  1.092193  ...   7.137  0.076914
# 1       27.727411   635.495566  581.626731  1.320198  ...  10.655  0.274434
# 2       58.114345   605.926500  587.555248  1.399310  ...  13.086  0.243612
# 3      113.070700   661.529541  613.900832  1.653586  ...  18.109  0.356415
# 4      178.453651   731.478841  645.722111  2.092302  ...  26.373  0.524751
# ...           ...          ...         ...       ...  ...     ...       ...
# 11929  175.337512   681.708518  628.990721  2.112396  ...  23.803  0.470617
# 11930  243.012437   747.474080  658.839691  2.504766  ...  32.671  0.647554
# 11931  331.609557   796.470080  680.396408  3.013422  ...  42.104  0.832088
# 11932  437.734498   893.052816  722.085597  3.631254  ...  58.064  1.165990
# 11933  645.935565  1038.531900  767.567808  4.531446  ...  86.067  1.689943
#
#         kMc    kMt  status_c_0  status_t_0 status_c_1 status_t_1 status_c_2  \
# 0      0.95  0.975       Emerg       Emerg      Emerg      Emerg      Emerg
# 1      0.95  0.975       Emerg       Emerg      Emerg      Emerg      Emerg
# 2      0.95  0.975       Emerg       Emerg      Emerg      Emerg      Emerg
# 3      0.95  0.975       Emerg       Emerg      Emerg      Emerg      Emerg
# 4      0.95  0.975       Emerg       Emerg      Emerg      Emerg      Emerg
# ...     ...    ...         ...         ...        ...        ...        ...
# 11929  1.00  1.000      Normal      Normal     Normal     Normal     Normal
# 11930  1.00  1.000      Normal      Normal     Normal     Normal     Normal
# 11931  1.00  1.000      Normal      Normal     Normal     Normal     Normal
# 11932  1.00  1.000      Normal      Normal     Normal     Normal     Normal
# 11933  1.00  1.000      Normal      Normal     Normal     Normal     Normal
#
#       status_t_2
# 0          Emerg
# 1          Emerg
# 2          Emerg
# 3          Emerg
# 4          Emerg
# ...          ...
# 11929     Normal
# 11930     Normal
# 11931     Normal
# 11932     Normal
# 11933     Normal
#
# [11934 rows x 22 columns]

# %%
df.groupby('status_c_0').count()['kMc']
# Out:
# status_c_0
# Emerg     3978
# Alert     3978
# Normal    3978
# Name: kMc, dtype: int64

# %%
df.groupby('status_t_0').count()['kMt']
# Out:
# status_t_0
# Emerg     4131
# Alert     3672
# Normal    4131
# Name: kMt, dtype: int64

# %%
df.groupby('status_c_1').count()['kMc']
# Out:
# status_c_1
# Emerg     1404
# Alert     1170
# Normal    9360
# Name: kMc, dtype: int64

# %%
df.groupby('status_t_1').count()['kMt']
# Out:
# status_t_1
# Emerg     1377
# Alert     1377
# Normal    9180
# Name: kMt, dtype: int64

# %%
df.groupby('status_c_2').count()['kMc']
# Out:
# status_c_2
# Emerg       702
# Alert       702
# Normal    10530
# Name: kMc, dtype: int64

# %%
df.groupby('status_t_2').count()['kMt']
# Out:
# status_t_2
# Emerg       918
# Alert       459
# Normal    10557
# Name: kMt, dtype: int64

# %% [markdown]
# ### Constatações:
# - Cenário 0: Classes balanceadas, não se faz necessária nenhuma técnica de balanceamento do dataset (consequência da escolha arbitrária dos limiares críticos.
# - Cenário 1: Classes desbalanceadas, pode acarretar viés no modelo devido à maior quantidade de exemplos da classe normal. Não faria sentido, contudo, utilizar alguma técnica de oversampling sobre dados simulados, quando se poderia gerar mais dados simulados para estas condições. Pode caber uma técnica de undersampling.
# - Cenário 2: Classes desbalanceadas do que no cenário 1, pode acarretar viés no modelo devido à maior quantidade de exemplos da classe normal. Não faria sentido, contudo, utilizar alguma técnica de oversampling sobre dados simulados, quando se poderia gerar mais dados simulados para estas condições. Pode caber uma técnica de undersampling.

# %% [markdown]
# ### Exclusão das variáveis kMc e kMt do dataset que será fornecido aos modelos de classificação, uma vez que as mesmas foram discretizadas nas variáveis status_c e status_t.

# %%
df2 = df.drop(columns=['kMc', 'kMt'])
df2
# Out:
#           lp          v           GTT          GTn          GGn          Ts  \
# 0      1.138   3.285108    355.331025  1307.353384  6523.884372    8.769179
# 1      2.088   4.932878   6508.994853  1394.558906  6836.383687   25.848960
# 2      3.144   9.256739   8586.669936  1377.919146  7081.543007   60.268974
# 3      4.161  11.455049  14737.377677  1549.917343  7852.449324  111.370792
# 4      5.140  15.457852  21570.033036  1939.042202  8561.228286  173.810801
# ...      ...        ...           ...          ...          ...         ...
# 11929  5.140  14.651664  21909.217094  1911.604470  8518.237680  175.628451
# 11930  6.175  18.499620  29731.940988  2321.029204  8861.118176  242.993486
# 11931  7.148  20.727082  39166.002585  2686.852984  9261.068704  332.394477
# 11932  8.206  24.557146  51148.243118  3099.907219  9408.364580  442.523179
# 11933  9.300  27.074587  72903.149154  3543.309629  9831.253053  641.241655
#
#                Tp          T48          T2       P48         P2      Pexh  \
# 0        7.512436   464.033912  550.587223  1.092193   6.025915  1.016685
# 1       27.727411   635.495566  581.626731  1.320198   7.071318  1.033962
# 2       58.114345   605.926500  587.555248  1.399310   7.551384  1.015596
# 3      113.070700   661.529541  613.900832  1.653586   8.937318  1.010129
# 4      178.453651   731.478841  645.722111  2.092302  11.170710  1.025160
# ...           ...          ...         ...       ...        ...       ...
# 11929  175.337512   681.708518  628.990721  2.112396  11.009221  1.026131
# 11930  243.012437   747.474080  658.839691  2.504766  13.076845  1.020045
# 11931  331.609557   796.470080  680.396408  3.013422  15.218171  1.049705
# 11932  437.734498   893.052816  722.085597  3.631254  18.502558  1.032058
# 11933  645.935565  1038.531900  767.567808  4.531446  22.352852  1.038365
#
#           TIC        mf status_c_0 status_t_0 status_c_1 status_t_1  \
# 0       7.137  0.076914      Emerg      Emerg      Emerg      Emerg
# 1      10.655  0.274434      Emerg      Emerg      Emerg      Emerg
# 2      13.086  0.243612      Emerg      Emerg      Emerg      Emerg
# 3      18.109  0.356415      Emerg      Emerg      Emerg      Emerg
# 4      26.373  0.524751      Emerg      Emerg      Emerg      Emerg
# ...       ...       ...        ...        ...        ...        ...
# 11929  23.803  0.470617     Normal     Normal     Normal     Normal
# 11930  32.671  0.647554     Normal     Normal     Normal     Normal
# 11931  42.104  0.832088     Normal     Normal     Normal     Normal
# 11932  58.064  1.165990     Normal     Normal     Normal     Normal
# 11933  86.067  1.689943     Normal     Normal     Normal     Normal
#
#       status_c_2 status_t_2
# 0          Emerg      Emerg
# 1          Emerg      Emerg
# 2          Emerg      Emerg
# 3          Emerg      Emerg
# 4          Emerg      Emerg
# ...          ...        ...
# 11929     Normal     Normal
# 11930     Normal     Normal
# 11931     Normal     Normal
# 11932     Normal     Normal
# 11933     Normal     Normal
#
# [11934 rows x 20 columns]

# %% [markdown]
# ## 4 - Modelagem

# %% [markdown]
# ### Divisão dos datasets de treino e teste para as duas variáveis target  para cada cenário k: status_c_k e status_t_k

# %%
from sklearn.model_selection import train_test_split

# %%
from math import floor

# %%
df2.columns
# Out:
# Index(['lp', 'v', 'GTT', 'GTn', 'GGn', 'Ts', 'Tp', 'T48', 'T2', 'P48', 'P2',
#        'Pexh', 'TIC', 'mf', 'status_c_0', 'status_t_0', 'status_c_1',
#        'status_t_1', 'status_c_2', 'status_t_2'],
#       dtype='object')

# %%
df2
# Out:
#           lp          v           GTT          GTn          GGn          Ts  \
# 0      1.138   3.285108    355.331025  1307.353384  6523.884372    8.769179
# 1      2.088   4.932878   6508.994853  1394.558906  6836.383687   25.848960
# 2      3.144   9.256739   8586.669936  1377.919146  7081.543007   60.268974
# 3      4.161  11.455049  14737.377677  1549.917343  7852.449324  111.370792
# 4      5.140  15.457852  21570.033036  1939.042202  8561.228286  173.810801
# ...      ...        ...           ...          ...          ...         ...
# 11929  5.140  14.651664  21909.217094  1911.604470  8518.237680  175.628451
# 11930  6.175  18.499620  29731.940988  2321.029204  8861.118176  242.993486
# 11931  7.148  20.727082  39166.002585  2686.852984  9261.068704  332.394477
# 11932  8.206  24.557146  51148.243118  3099.907219  9408.364580  442.523179
# 11933  9.300  27.074587  72903.149154  3543.309629  9831.253053  641.241655
#
#                Tp          T48          T2       P48         P2      Pexh  \
# 0        7.512436   464.033912  550.587223  1.092193   6.025915  1.016685
# 1       27.727411   635.495566  581.626731  1.320198   7.071318  1.033962
# 2       58.114345   605.926500  587.555248  1.399310   7.551384  1.015596
# 3      113.070700   661.529541  613.900832  1.653586   8.937318  1.010129
# 4      178.453651   731.478841  645.722111  2.092302  11.170710  1.025160
# ...           ...          ...         ...       ...        ...       ...
# 11929  175.337512   681.708518  628.990721  2.112396  11.009221  1.026131
# 11930  243.012437   747.474080  658.839691  2.504766  13.076845  1.020045
# 11931  331.609557   796.470080  680.396408  3.013422  15.218171  1.049705
# 11932  437.734498   893.052816  722.085597  3.631254  18.502558  1.032058
# 11933  645.935565  1038.531900  767.567808  4.531446  22.352852  1.038365
#
#           TIC        mf status_c_0 status_t_0 status_c_1 status_t_1  \
# 0       7.137  0.076914      Emerg      Emerg      Emerg      Emerg
# 1      10.655  0.274434      Emerg      Emerg      Emerg      Emerg
# 2      13.086  0.243612      Emerg      Emerg      Emerg      Emerg
# 3      18.109  0.356415      Emerg      Emerg      Emerg      Emerg
# 4      26.373  0.524751      Emerg      Emerg      Emerg      Emerg
# ...       ...       ...        ...        ...        ...        ...
# 11929  23.803  0.470617     Normal     Normal     Normal     Normal
# 11930  32.671  0.647554     Normal     Normal     Normal     Normal
# 11931  42.104  0.832088     Normal     Normal     Normal     Normal
# 11932  58.064  1.165990     Normal     Normal     Normal     Normal
# 11933  86.067  1.689943     Normal     Normal     Normal     Normal
#
#       status_c_2 status_t_2
# 0          Emerg      Emerg
# 1          Emerg      Emerg
# 2          Emerg      Emerg
# 3          Emerg      Emerg
# 4          Emerg      Emerg
# ...          ...        ...
# 11929     Normal     Normal
# 11930     Normal     Normal
# 11931     Normal     Normal
# 11932     Normal     Normal
# 11933     Normal     Normal
#
# [11934 rows x 20 columns]

# %%
X = df2.drop(columns=['status_c_0', 'status_t_0', 'status_c_1', 'status_t_1', 'status_c_2', 'status_t_2'])

# %%
y = [df[col] for col in ['status_c_0', 'status_t_0', 'status_c_1', 'status_t_1', 'status_c_2', 'status_t_2']]

# %%
# Cria uma lista de dados de treino e teste de acordo com a lista de vetores de saída y
# Índice 0: X_train, X_test, y_train, y_test para a saída status_c_0, etc.
conj_treino_teste = []
for saida in y:
    X_train, X_test, y_train, y_test = train_test_split(X, saida, test_size=0.3)
    conj_treino_teste.append([X_train, X_test, y_train, y_test])

# %% [markdown]
# ## Teste de modelos de classificação

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.ensemble import AdaBoostClassifier
from sklearn.metrics import classification_report

# %%
import warnings
warnings.simplefilter("ignore")

# %%
# Para cada saída que se quer prever, cria-se uma instância de um dos modelos de classificação
# Ou seja, 6 modelos para 6 saídas, 36 treinamentos distintos
modelos = [
    {'DecisionTree_comp_0': DecisionTreeClassifier(),
    'RandomForest_comp_0': RandomForestClassifier(),
    'KNN_comp_0': KNeighborsClassifier(),
    'GaussianNB_comp_0': GaussianNB(),
    'SVC_comp_0': SVC(),
    'AdaBoost_comp_0': AdaBoostClassifier()},
    
    {'DecisionTree_turb_0': DecisionTreeClassifier(),
    'RandomForest_turb_0': RandomForestClassifier(),
    'KNN_turb_0': KNeighborsClassifier(),
    'GaussianNB_turb_0': GaussianNB(),
    'SVC_turb_0': SVC(),
    'AdaBoost_turb_0': AdaBoostClassifier()},
    
    {'DecisionTree_comp_1': DecisionTreeClassifier(),
    'RandomForest_comp_1': RandomForestClassifier(),
    'KNN_comp_1': KNeighborsClassifier(),
    'GaussianNB_comp_1': GaussianNB(),
    'SVC_comp_1': SVC(),
    'AdaBoost_comp_1': AdaBoostClassifier()},    
    
    {'DecisionTree_turb_1': DecisionTreeClassifier(),
    'RandomForest_turb_1': RandomForestClassifier(),
    'KNN_turb_1': KNeighborsClassifier(),
    'GaussianNB_turb_1': GaussianNB(),
    'SVC_turb_1': SVC(),
    'AdaBoost_turb_1': AdaBoostClassifier()},
    
    {'DecisionTree_comp_2': DecisionTreeClassifier(),
    'RandomForest_comp_2': RandomForestClassifier(),
    'KNN_comp_2': KNeighborsClassifier(),
    'GaussianNB_comp_2': GaussianNB(),
    'SVC_comp_2': SVC(),
    'AdaBoost_comp_2': AdaBoostClassifier()},
    
    {'DecisionTree_turb_2': DecisionTreeClassifier(),
    'RandomForest_turb_2': RandomForestClassifier(),
    'KNN_turb_2': KNeighborsClassifier(),
    'GaussianNB_turb_2': GaussianNB(),
    'SVC_turb_2': SVC(),
    'AdaBoost_turb_2': AdaBoostClassifier()}]

# %%
result = {'Modelo': [], 'Estagio': [], 'Cenario': [], 'Acuracia': [], 'Recall_Emerg': [], 'F1-score_Emerg': []}

# %%
# %%time
i = 0
for dic_mod, data in zip(modelos, conj_treino_teste):
    for mod in dic_mod:
        print('#################################################################')
        
        result['Modelo'].append(mod)
        print(f'Modelo {mod}')
               
        # São 12 modelos para cada cenário
        result['Cenario'].append(floor(i/12))
        print(f'Cenário {floor(i/12)}')

        # Primeira metade dos modelos do cenário são compressor, outra metade turbina
        if(floor(i/6)%2) == 0:
            result['Estagio'].append('Compressor')
            print('Estágio: Compressor')
        else:
            result['Estagio'].append('Turbina')
            print('Estágio: Turbina')
            
        i+=1
        
        # Treinando o modelo
        dic_mod[mod].fit(data[0], data[2])
        
        # Fazendo previsões
        Y_pred = dic_mod[mod].predict(data[1])
        
        # Resultado
        report = classification_report(data[3], Y_pred, output_dict=True)
        print(report)
        
        # Gravando resultados do report em um dataframe para comparação posterior
        result['Acuracia'].append(report['accuracy'])
        result['Recall_Emerg'].append(report['Emerg']['recall'])
        result['F1-score_Emerg'].append(report['Emerg']['f1-score'])
    
resultados = pd.DataFrame.from_dict(result)
# Out:
# #################################################################
# Modelo DecisionTree_comp_0
# Cenário 0
# Estágio: Compressor
# {'Alert': {'precision': 0.8121314237573716, 'recall': 0.8066945606694561, 'f1-score': 0.8094038623005878, 'support': 1195}, 'Emerg': {'precision': 0.8913738019169329, 'recall': 0.901453957996769, 'f1-score': 0.8963855421686747, 'support': 1238}, 'Normal': {'precision': 0.9001751313485113, 'recall': 0.8954703832752613, 'f1-score': 0.8978165938864628, 'support': 1148}, 'accuracy': 0.8679139905054454, 'macro avg': {'precision': 0.8678934523409385, 'recall': 0.8678729673138288, 'f1-score': 0.867868666118575, 'support': 3581}, 'weighted avg': {'precision': 0.8677517087269794, 'recall': 0.8679139905054454, 'f1-score': 0.867818030280838, 'support': 3581}}
# #################################################################
# Modelo RandomForest_comp_0
# Cenário 0
# Estágio: Compressor
# {'Alert': {'precision': 0.8663829787234043, 'recall': 0.8518828451882845, 'f1-score': 0.8590717299578059, 'support': 1195}, 'Emerg': {'precision': 0.9118110236220472, 'recall': 0.9353796445880452, 'f1-score': 0.9234449760765551, 'support': 1238}, 'Normal': {'precision': 0.9392605633802817, 'recall': 0.9294425087108014, 'f1-score': 0.9343257443082311, 'support': 1148}, 'accuracy': 0.9056129572745043, 'macro avg': {'precision': 0.9058181885752443, 'recall': 0.9055683328290437, 'f1-score': 0.9056141501141974, 'support': 3581}, 'weighted avg': {'precision': 0.9054512241215097, 'recall': 0.9056129572745043, 'f1-score': 0.9054514247830782, 'support': 3581}}
# #################################################################
# Modelo KNN_comp_0
# Cenário 0
# Estágio: Compressor
# {'Alert': {'precision': 0.39119496855345914, 'recall': 0.5205020920502093, 'f1-score': 0.44667863554757636, 'support': 1195}, 'Emerg': {'precision': 0.5445269016697588, 'recall': 0.47415185783521807, 'f1-score': 0.5069084628670121, 'support': 1238}, 'Normal': {'precision': 0.5958378970427163, 'recall': 0.4738675958188153, 'f1-score': 0.5278990781174188, 'support': 1148}, 'accuracy': 0.4895280647863725, 'macro avg': {'precision': 0.5105199224219781, 'recall': 0.48950718190141423, 'f1-score': 0.49382872551066903, 'support': 3581}, 'weighted avg': {'precision': 0.5098084885488923, 'recall': 0.4895280647863725, 'f1-score': 0.4935386171984115, 'support': 3581}}
# #################################################################
# Modelo GaussianNB_comp_0
# Cenário 0
# Estágio: Compressor
# {'Alert': {'precision': 0.3386454183266932, 'recall': 0.21338912133891214, 'f1-score': 0.26180698151950715, 'support': 1195}, 'Emerg': {'precision': 0.5863453815261044, 'recall': 0.11793214862681745, 'f1-score': 0.1963685272360457, 'support': 1238}, 'Normal': {'precision': 0.3338503295851105, 'recall': 0.75, 'f1-score': 0.4620338073517575, 'support': 1148}, 'accuracy': 0.35241552638927676, 'macro avg': {'precision': 0.419613709812636, 'recall': 0.36044042332190984, 'f1-score': 0.3067364387024368, 'support': 3581}, 'weighted avg': {'precision': 0.4227414229526452, 'recall': 0.35241552638927676, 'f1-score': 0.30337290993405563, 'support': 3581}}
# #################################################################
# Modelo SVC_comp_0
# Cenário 0
# Estágio: Compressor
# {'Alert': {'precision': 0.3583061889250814, 'recall': 0.18410041841004185, 'f1-score': 0.24322830292979547, 'support': 1195}, 'Emerg': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 1238}, 'Normal': {'precision': 0.3259184361307718, 'recall': 0.8423344947735192, 'f1-score': 0.4699878493317132, 'support': 1148}, 'accuracy': 0.33147165596202177, 'macro avg': {'precision': 0.22807487501861776, 'recall': 0.342144971061187, 'f1-score': 0.2377387174205029, 'support': 3581}, 'weighted avg': {'precision': 0.22405201352795262, 'recall': 0.33147165596202177, 'f1-score': 0.23183576460036648, 'support': 3581}}
# #################################################################
# Modelo AdaBoost_comp_0
# Cenário 0
# Estágio: Compressor
# {'Alert': {'precision': 0.46334134615384615, 'recall': 0.6451882845188285, 'f1-score': 0.5393494228751312, 'support': 1195}, 'Emerg': {'precision': 0.7438894792773645, 'recall': 0.5654281098546042, 'f1-score': 0.6424965580541534, 'support': 1238}, 'Normal': {'precision': 0.6659836065573771, 'recall': 0.5662020905923345, 'f1-score': 0.6120527306967986, 'support': 1148}, 'accuracy': 0.5922926556827702, 'macro avg': {'precision': 0.6244048106628625, 'recall': 0.5922728283219224, 'f1-score': 0.5979662372086944, 'support': 3581}, 'weighted avg': {'precision': 0.6252938465029579, 'recall': 0.5922926556827702, 'f1-score': 0.5983160664749367, 'support': 3581}}
# #################################################################
# Modelo DecisionTree_turb_0
# Cenário 0
# Estágio: Turbina
# {'Alert': {'precision': 0.6060054595086443, 'recall': 0.6132596685082873, 'f1-score': 0.6096109839816933, 'support': 1086}, 'Emerg': {'precision': 0.7981952420016407, 'recall': 0.7904142973192526, 'f1-score': 0.7942857142857144, 'support': 1231}, 'Normal': {'precision': 0.7878068091844814, 'recall': 0.7871835443037974, 'f1-score': 0.7874950534230314, 'support': 1264}, 'accuracy': 0.7355487294051941, 'macro avg': {'precision': 0.7306691702315887, 'recall': 0.7302858367104458, 'f1-score': 0.7304639172301464, 'support': 3581}, 'weighted avg': {'precision': 0.736243529388325, 'recall': 0.7355487294051941, 'f1-score': 0.7358829909010178, 'support': 3581}}
# #################################################################
# Modelo RandomForest_turb_0
# Cenário 0
# Estágio: Turbina
# {'Alert': {'precision': 0.7142857142857143, 'recall': 0.6675874769797422, 'f1-score': 0.6901475487862923, 'support': 1086}, 'Emerg': {'precision': 0.8438985736925515, 'recall': 0.8651502843216897, 'f1-score': 0.8543922984356198, 'support': 1231}, 'Normal': {'precision': 0.8412576687116564, 'recall': 0.867879746835443, 'f1-score': 0.8543613707165109, 'support': 1264}, 'accuracy': 0.8061993856464674, 'macro avg': {'precision': 0.7998139855633074, 'recall': 0.8002058360456249, 'f1-score': 0.7996337393128076, 'support': 3581}, 'weighted avg': {'precision': 0.8036590681880342, 'recall': 0.8061993856464674, 'f1-score': 0.8045713292213993, 'support': 3581}}
# #################################################################
# Modelo KNN_turb_0
# Cenário 0
# Estágio: Turbina
# {'Alert': {'precision': 0.3053536021150033, 'recall': 0.425414364640884, 'f1-score': 0.3555213543670642, 'support': 1086}, 'Emerg': {'precision': 0.4425287356321839, 'recall': 0.437855402112104, 'f1-score': 0.44017966516945695, 'support': 1231}, 'Normal': {'precision': 0.4576470588235294, 'recall': 0.307753164556962, 'f1-score': 0.3680227057710501, 'support': 1264}, 'accuracy': 0.38815973191845854, 'macro avg': {'precision': 0.40184313219023887, 'recall': 0.39034097710331667, 'f1-score': 0.38790790843585715, 'support': 3581}, 'weighted avg': {'precision': 0.40626438643201707, 'recall': 0.38815973191845854, 'f1-score': 0.38903603986619395, 'support': 3581}}
# #################################################################
# Modelo GaussianNB_turb_0
# Cenário 0
# Estágio: Turbina
# {'Alert': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 1086}, 'Emerg': {'precision': 0.3321888412017167, 'recall': 0.314378554021121, 'f1-score': 0.32303839732888145, 'support': 1231}, 'Normal': {'precision': 0.3518211920529801, 'recall': 0.6724683544303798, 'f1-score': 0.46195652173913043, 'support': 1264}, 'accuracy': 0.34543423624685843, 'macro avg': {'precision': 0.22800334441823225, 'recall': 0.3289489694838336, 'f1-score': 0.2616649730226706, 'support': 3581}, 'weighted avg': {'precision': 0.23837655690429493, 'recall': 0.34543423624685843, 'f1-score': 0.27410592309134707, 'support': 3581}}
# #################################################################
# Modelo SVC_turb_0
# Cenário 0
# Estágio: Turbina
# {'Alert': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 1086}, 'Emerg': {'precision': 0.34375872661267803, 'recall': 1.0, 'f1-score': 0.5116375727348296, 'support': 1231}, 'Normal': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 1264}, 'accuracy': 0.34375872661267803, 'macro avg': {'precision': 0.11458624220422602, 'recall': 0.3333333333333333, 'f1-score': 0.17054585757827653, 'support': 3581}, 'weighted avg': {'precision': 0.11817006212236991, 'recall': 0.34375872661267803, 'f1-score': 0.17587988049052644, 'support': 3581}}
# #################################################################
# Modelo AdaBoost_turb_0
# Cenário 0
# Estágio: Turbina
# {'Alert': {'precision': 0.398972602739726, 'recall': 0.214548802946593, 'f1-score': 0.2790419161676647, 'support': 1086}, 'Emerg': {'precision': 0.6073223259152908, 'recall': 0.6872461413484972, 'f1-score': 0.6448170731707317, 'support': 1231}, 'Normal': {'precision': 0.5723192019950125, 'recall': 0.7262658227848101, 'f1-score': 0.6401673640167364, 'support': 1264}, 'accuracy': 0.5576654565763753, 'macro avg': {'precision': 0.5262047102166765, 'recall': 0.5426869223599667, 'f1-score': 0.5213421177850442, 'support': 3581}, 'weighted avg': {'precision': 0.5317814859253731, 'recall': 0.5576654565763753, 'f1-score': 0.5322482228842249, 'support': 3581}}
# #################################################################
# Modelo DecisionTree_comp_1
# Cenário 1
# Estágio: Compressor
# {'Alert': {'precision': 0.4610951008645533, 'recall': 0.46647230320699706, 'f1-score': 0.463768115942029, 'support': 343}, 'Emerg': {'precision': 0.7164179104477612, 'recall': 0.6939759036144578, 'f1-score': 0.7050183598531211, 'support': 415}, 'Normal': {'precision': 0.9565677966101694, 'recall': 0.9596174282678002, 'f1-score': 0.9580901856763925, 'support': 2823}, 'accuracy': 0.8815973191845853, 'macro avg': {'precision': 0.7113602693074946, 'recall': 0.7066885450297516, 'f1-score': 0.7089588871571809, 'support': 3581}, 'weighted avg': {'precision': 0.8812789562309051, 'recall': 0.8815973191845853, 'f1-score': 0.8814140400088292, 'support': 3581}}
# #################################################################
# Modelo RandomForest_comp_1
# Cenário 1
# Estágio: Compressor
# {'Alert': {'precision': 0.5532994923857868, 'recall': 0.3177842565597668, 'f1-score': 0.4037037037037037, 'support': 343}, 'Emerg': {'precision': 0.7934508816120907, 'recall': 0.7590361445783133, 'f1-score': 0.7758620689655173, 'support': 415}, 'Normal': {'precision': 0.933712755272849, 'recall': 0.9879560750974141, 'f1-score': 0.9600688468158347, 'support': 2823}, 'accuracy': 0.8972354091036023, 'macro avg': {'precision': 0.7601543764235755, 'recall': 0.6882588254118313, 'f1-score': 0.713211539828352, 'support': 3581}, 'weighted avg': {'precision': 0.8810206506262482, 'recall': 0.8972354091036023, 'f1-score': 0.8854307410087019, 'support': 3581}}
# #################################################################
# Modelo KNN_comp_1
# Cenário 1
# Estágio: Compressor
# {'Alert': {'precision': 0.1830065359477124, 'recall': 0.08163265306122448, 'f1-score': 0.1129032258064516, 'support': 343}, 'Emerg': {'precision': 0.3508771929824561, 'recall': 0.14457831325301204, 'f1-score': 0.20477815699658702, 'support': 415}, 'Normal': {'precision': 0.81639545594105, 'recall': 0.9419057739992915, 'f1-score': 0.874671052631579, 'support': 2823}, 'accuracy': 0.7671041608489249, 'macro avg': {'precision': 0.4500930616237395, 'recall': 0.38937224677117604, 'f1-score': 0.3974508118115392, 'support': 3581}, 'weighted avg': {'precision': 0.7017787347219684, 'recall': 0.7671041608489249, 'f1-score': 0.7240729190684567, 'support': 3581}}
# #################################################################
# Modelo GaussianNB_comp_1
# Cenário 1
# Estágio: Compressor
# {'Alert': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 343}, 'Emerg': {'precision': 1.0, 'recall': 0.0024096385542168677, 'f1-score': 0.004807692307692308, 'support': 415}, 'Normal': {'precision': 0.7885474860335195, 'recall': 1.0, 'f1-score': 0.8817741683585819, 'support': 2823}, 'accuracy': 0.7886065344875733, 'macro avg': {'precision': 0.5961824953445065, 'recall': 0.334136546184739, 'f1-score': 0.29552728688875807, 'support': 3581}, 'weighted avg': {'precision': 0.737522913452283, 'recall': 0.7886065344875733, 'f1-score': 0.6956837949131441, 'support': 3581}}
# #################################################################
# Modelo SVC_comp_1
# Cenário 1
# Estágio: Compressor
# {'Alert': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 343}, 'Emerg': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 415}, 'Normal': {'precision': 0.7883272828818766, 'recall': 1.0, 'f1-score': 0.8816364772017489, 'support': 2823}, 'accuracy': 0.7883272828818766, 'macro avg': {'precision': 0.26277576096062555, 'recall': 0.3333333333333333, 'f1-score': 0.29387882573391627, 'support': 3581}, 'weighted avg': {'precision': 0.6214599049359222, 'recall': 0.7883272828818766, 'f1-score': 0.6950180885620042, 'support': 3581}}
# #################################################################
# Modelo AdaBoost_comp_1
# Cenário 1
# Estágio: Compressor
# {'Alert': {'precision': 0.5142857142857142, 'recall': 0.052478134110787174, 'f1-score': 0.09523809523809525, 'support': 343}, 'Emerg': {'precision': 0.6616541353383458, 'recall': 0.21204819277108433, 'f1-score': 0.32116788321167883, 'support': 415}, 'Normal': {'precision': 0.8230295927336654, 'recall': 0.9950407368048175, 'f1-score': 0.9008980115458627, 'support': 2823}, 'accuracy': 0.814018430605976, 'macro avg': {'precision': 0.6663231474525751, 'recall': 0.419855687895563, 'f1-score': 0.43910132999854556, 'support': 3581}, 'weighted avg': {'precision': 0.7747553773952948, 'recall': 0.814018430605976, 'f1-score': 0.7565446592553711, 'support': 3581}}
# #################################################################
# Modelo DecisionTree_turb_1
# Cenário 1
# Estágio: Turbina
# {'Alert': {'precision': 0.36065573770491804, 'recall': 0.3632075471698113, 'f1-score': 0.36192714453584024, 'support': 424}, 'Emerg': {'precision': 0.5555555555555556, 'recall': 0.5415617128463476, 'f1-score': 0.5484693877551019, 'support': 397}, 'Normal': {'precision': 0.9139862667148536, 'recall': 0.9163043478260869, 'f1-score': 0.9151438393341776, 'support': 2760}, 'accuracy': 0.8092711533091316, 'macro avg': {'precision': 0.610065853325109, 'recall': 0.6070245359474152, 'f1-score': 0.6085134572083732, 'support': 3581}, 'weighted avg': {'precision': 0.8087337851090302, 'recall': 0.8092711533091316, 'f1-score': 0.8089909111377553, 'support': 3581}}
# #################################################################
# Modelo RandomForest_turb_1
# Cenário 1
# Estágio: Turbina
# {'Alert': {'precision': 0.37662337662337664, 'recall': 0.13679245283018868, 'f1-score': 0.20069204152249134, 'support': 424}, 'Emerg': {'precision': 0.6591639871382636, 'recall': 0.5163727959697733, 'f1-score': 0.5790960451977402, 'support': 397}, 'Normal': {'precision': 0.8671373555840821, 'recall': 0.9789855072463768, 'f1-score': 0.9196732471068754, 'support': 2760}, 'accuracy': 0.8279810108908127, 'macro avg': {'precision': 0.6343082397819075, 'recall': 0.5440502520154462, 'f1-score': 0.5664871112757023, 'support': 3581}, 'weighted avg': {'precision': 0.7860026573566794, 'recall': 0.8279810108908127, 'f1-score': 0.7967865729025454, 'support': 3581}}
# #################################################################
# Modelo KNN_turb_1
# Cenário 1
# Estágio: Turbina
# {'Alert': {'precision': 0.1871345029239766, 'recall': 0.07547169811320754, 'f1-score': 0.10756302521008404, 'support': 424}, 'Emerg': {'precision': 0.1893491124260355, 'recall': 0.08060453400503778, 'f1-score': 0.11307420494699646, 'support': 397}, 'Normal': {'precision': 0.7855600123418698, 'recall': 0.922463768115942, 'f1-score': 0.848525245792368, 'support': 2760}, 'accuracy': 0.7288466908684725, 'macro avg': {'precision': 0.3873478758972939, 'recall': 0.3595133334113958, 'f1-score': 0.3563874919831495, 'support': 3581}, 'weighted avg': {'precision': 0.6486071658577108, 'recall': 0.7288466908684725, 'f1-score': 0.6792591065177238, 'support': 3581}}
# #################################################################
# Modelo GaussianNB_turb_1
# Cenário 1
# Estágio: Turbina
# {'Alert': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 424}, 'Emerg': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 397}, 'Normal': {'precision': 0.7707344317229824, 'recall': 1.0, 'f1-score': 0.8705251537612364, 'support': 2760}, 'accuracy': 0.7707344317229824, 'macro avg': {'precision': 0.2569114772409941, 'recall': 0.3333333333333333, 'f1-score': 0.2901750512537455, 'support': 3581}, 'weighted avg': {'precision': 0.5940315642433487, 'recall': 0.7707344317229824, 'f1-score': 0.6709437096847284, 'support': 3581}}
# #################################################################
# Modelo SVC_turb_1
# Cenário 1
# Estágio: Turbina
# {'Alert': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 424}, 'Emerg': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 397}, 'Normal': {'precision': 0.7707344317229824, 'recall': 1.0, 'f1-score': 0.8705251537612364, 'support': 2760}, 'accuracy': 0.7707344317229824, 'macro avg': {'precision': 0.2569114772409941, 'recall': 0.3333333333333333, 'f1-score': 0.2901750512537455, 'support': 3581}, 'weighted avg': {'precision': 0.5940315642433487, 'recall': 0.7707344317229824, 'f1-score': 0.6709437096847284, 'support': 3581}}
# #################################################################
# Modelo AdaBoost_turb_1
# Cenário 1
# Estágio: Turbina
# {'Alert': {'precision': 0.2777777777777778, 'recall': 0.03537735849056604, 'f1-score': 0.06276150627615062, 'support': 424}, 'Emerg': {'precision': 0.5277777777777778, 'recall': 0.04785894206549118, 'f1-score': 0.08775981524249421, 'support': 397}, 'Normal': {'precision': 0.7840160412489258, 'recall': 0.9916666666666667, 'f1-score': 0.8756998880179171, 'support': 2760}, 'accuracy': 0.7738061993856464, 'macro avg': {'precision': 0.5298571989348271, 'recall': 0.3583009890742413, 'f1-score': 0.3420737365121873, 'support': 3581}, 'weighted avg': {'precision': 0.6956687599560433, 'recall': 0.7738061993856464, 'f1-score': 0.6920924926673581, 'support': 3581}}
# #################################################################
# Modelo DecisionTree_comp_2
# Cenário 2
# Estágio: Compressor
# {'Alert': {'precision': 0.31521739130434784, 'recall': 0.4009216589861751, 'f1-score': 0.35294117647058826, 'support': 217}, 'Emerg': {'precision': 0.5053191489361702, 'recall': 0.45454545454545453, 'f1-score': 0.4785894206549119, 'support': 209}, 'Normal': {'precision': 0.9669554058389477, 'recall': 0.9553090332805071, 'f1-score': 0.9610969387755102, 'support': 3155}, 'accuracy': 0.8924881318067579, 'macro avg': {'precision': 0.5958306486931552, 'recall': 0.6035920489373789, 'f1-score': 0.5975425119670034, 'support': 3581}, 'weighted avg': {'precision': 0.9005189001571021, 'recall': 0.8924881318067579, 'f1-score': 0.8960832912727531, 'support': 3581}}
# #################################################################
# Modelo RandomForest_comp_2
# Cenário 2
# Estágio: Compressor
# {'Alert': {'precision': 0.47058823529411764, 'recall': 0.18433179723502305, 'f1-score': 0.26490066225165565, 'support': 217}, 'Emerg': {'precision': 0.7019867549668874, 'recall': 0.507177033492823, 'f1-score': 0.5888888888888889, 'support': 209}, 'Normal': {'precision': 0.9357249626307922, 'recall': 0.9920760697305864, 'f1-score': 0.9630769230769232, 'support': 3155}, 'accuracy': 0.9148282602624965, 'macro avg': {'precision': 0.7027666509639324, 'recall': 0.5611949668194774, 'f1-score': 0.6056221580724892, 'support': 3581}, 'weighted avg': {'precision': 0.8938969941209305, 'recall': 0.9148282602624965, 'f1-score': 0.8989301630254342, 'support': 3581}}
# #################################################################
# Modelo KNN_comp_2
# Cenário 2
# Estágio: Compressor
# {'Alert': {'precision': 0.16666666666666666, 'recall': 0.041474654377880185, 'f1-score': 0.06642066420664205, 'support': 217}, 'Emerg': {'precision': 0.21951219512195122, 'recall': 0.0430622009569378, 'f1-score': 0.07200000000000001, 'support': 209}, 'Normal': {'precision': 0.8866896156052783, 'recall': 0.9797147385103011, 'f1-score': 0.9308839030266526, 'support': 3155}, 'accuracy': 0.8681932421111421, 'macro avg': {'precision': 0.42428949246463205, 'recall': 0.35475053128170636, 'f1-score': 0.3564348557444315, 'support': 3581}, 'weighted avg': {'precision': 0.8041190875961484, 'recall': 0.8681932421111421, 'f1-score': 0.8283719626310891, 'support': 3581}}
# #################################################################
# Modelo GaussianNB_comp_2
# Cenário 2
# Estágio: Compressor
# {'Alert': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 217}, 'Emerg': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 209}, 'Normal': {'precision': 0.8810388159731919, 'recall': 1.0, 'f1-score': 0.9367577197149644, 'support': 3155}, 'accuracy': 0.8810388159731919, 'macro avg': {'precision': 0.2936796053243973, 'recall': 0.3333333333333333, 'f1-score': 0.31225257323832145, 'support': 3581}, 'weighted avg': {'precision': 0.7762293952514439, 'recall': 0.8810388159731919, 'f1-score': 0.8253199122314193, 'support': 3581}}
# #################################################################
# Modelo SVC_comp_2
# Cenário 2
# Estágio: Compressor
# {'Alert': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 217}, 'Emerg': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 209}, 'Normal': {'precision': 0.8810388159731919, 'recall': 1.0, 'f1-score': 0.9367577197149644, 'support': 3155}, 'accuracy': 0.8810388159731919, 'macro avg': {'precision': 0.2936796053243973, 'recall': 0.3333333333333333, 'f1-score': 0.31225257323832145, 'support': 3581}, 'weighted avg': {'precision': 0.7762293952514439, 'recall': 0.8810388159731919, 'f1-score': 0.8253199122314193, 'support': 3581}}
# #################################################################
# Modelo AdaBoost_comp_2
# Cenário 2
# Estágio: Compressor
# {'Alert': {'precision': 0.3448275862068966, 'recall': 0.09216589861751152, 'f1-score': 0.14545454545454548, 'support': 217}, 'Emerg': {'precision': 0.6, 'recall': 0.0861244019138756, 'f1-score': 0.1506276150627615, 'support': 209}, 'Normal': {'precision': 0.8972230174634984, 'recall': 0.9933438985736925, 'f1-score': 0.9428399518652226, 'support': 3155}, 'accuracy': 0.8857860932700363, 'macro avg': {'precision': 0.6140168678901317, 'recall': 0.3905447330350265, 'f1-score': 0.4129740374608432, 'support': 3581}, 'weighted avg': {'precision': 0.8464021799229918, 'recall': 0.8857860932700363, 'f1-score': 0.8482839586837562, 'support': 3581}}
# #################################################################
# Modelo DecisionTree_turb_2
# Cenário 2
# Estágio: Turbina
# {'Alert': {'precision': 0.06875, 'recall': 0.08208955223880597, 'f1-score': 0.07482993197278912, 'support': 134}, 'Emerg': {'precision': 0.462882096069869, 'recall': 0.35333333333333333, 'f1-score': 0.4007561436672968, 'support': 300}, 'Normal': {'precision': 0.9301378446115288, 'recall': 0.9434381951064506, 'f1-score': 0.9367408108534468, 'support': 3147}, 'accuracy': 0.8617704551801173, 'macro avg': {'precision': 0.48725664689379933, 'recall': 0.4596203602261966, 'f1-score': 0.4707756288311776, 'support': 3581}, 'weighted avg': {'precision': 0.8587603814055969, 'recall': 0.8617704551801173, 'f1-score': 0.8595859775873611, 'support': 3581}}
# #################################################################
# Modelo RandomForest_turb_2
# Cenário 2
# Estágio: Turbina
# {'Alert': {'precision': 0.07692307692307693, 'recall': 0.007462686567164179, 'f1-score': 0.01360544217687075, 'support': 134}, 'Emerg': {'precision': 0.6627906976744186, 'recall': 0.19, 'f1-score': 0.29533678756476683, 'support': 300}, 'Normal': {'precision': 0.89862148190695, 'recall': 0.994280266920877, 'f1-score': 0.9440337909186906, 'support': 3147}, 'accuracy': 0.8899748673554873, 'macro avg': {'precision': 0.5461117521681486, 'recall': 0.3972476511626804, 'f1-score': 0.4176586735534427, 'support': 3581}, 'weighted avg': {'precision': 0.8481169240913682, 'recall': 0.8899748673554873, 'f1-score': 0.8548725231896817, 'support': 3581}}
# #################################################################
# Modelo KNN_turb_2
# Cenário 2
# Estágio: Turbina
# {'Alert': {'precision': 0.07142857142857142, 'recall': 0.007462686567164179, 'f1-score': 0.013513513513513514, 'support': 134}, 'Emerg': {'precision': 0.225, 'recall': 0.03, 'f1-score': 0.052941176470588235, 'support': 300}, 'Normal': {'precision': 0.8820527360362914, 'recall': 0.988560533841754, 'f1-score': 0.9322744980521426, 'support': 3147}, 'accuracy': 0.8715442613795029, 'macro avg': {'precision': 0.3928271024882876, 'recall': 0.342007740136306, 'f1-score': 0.3329097293454148, 'support': 3581}, 'weighted avg': {'precision': 0.7966745012224623, 'recall': 0.8715442613795029, 'f1-score': 0.8242281511092098, 'support': 3581}}
# #################################################################
# Modelo GaussianNB_turb_2
# Cenário 2
# Estágio: Turbina
# {'Alert': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 134}, 'Emerg': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 300}, 'Normal': {'precision': 0.878804803127618, 'recall': 1.0, 'f1-score': 0.9354934601664685, 'support': 3147}, 'accuracy': 0.878804803127618, 'macro avg': {'precision': 0.29293493437587265, 'recall': 0.3333333333333333, 'f1-score': 0.31183115338882283, 'support': 3581}, 'weighted avg': {'precision': 0.7722978820001715, 'recall': 0.878804803127618, 'f1-score': 0.8221161460887675, 'support': 3581}}
# #################################################################
# Modelo SVC_turb_2
# Cenário 2
# Estágio: Turbina
# {'Alert': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 134}, 'Emerg': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 300}, 'Normal': {'precision': 0.878804803127618, 'recall': 1.0, 'f1-score': 0.9354934601664685, 'support': 3147}, 'accuracy': 0.878804803127618, 'macro avg': {'precision': 0.29293493437587265, 'recall': 0.3333333333333333, 'f1-score': 0.31183115338882283, 'support': 3581}, 'weighted avg': {'precision': 0.7722978820001715, 'recall': 0.878804803127618, 'f1-score': 0.8221161460887675, 'support': 3581}}
# #################################################################
# Modelo AdaBoost_turb_2
# Cenário 2
# Estágio: Turbina
# {'Alert': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 134}, 'Emerg': {'precision': 0.47368421052631576, 'recall': 0.03, 'f1-score': 0.05642633228840126, 'support': 300}, 'Normal': {'precision': 0.8817415730337078, 'recall': 0.9974578964092787, 'f1-score': 0.9360369762934247, 'support': 3147}, 'accuracy': 0.8790840547333147, 'macro avg': {'precision': 0.4518085945200079, 'recall': 0.34248596546975957, 'f1-score': 0.3308211028606087, 'support': 3581}, 'weighted avg': {'precision': 0.8145618524141226, 'recall': 0.8790840547333147, 'f1-score': 0.8273209338402481, 'support': 3581}}
# CPU times: user 41.9 s, sys: 416 ms, total: 42.3 s
# Wall time: 42.3 s

# %%
# Dataset resultante com os resultados coletados do treinamento dos modelos
resultados
# Out:
#                  Modelo     Estagio  Cenario  Acuracia  Recall_Emerg  \
# 0   DecisionTree_comp_0  Compressor        0  0.867914      0.901454
# 1   RandomForest_comp_0  Compressor        0  0.905613      0.935380
# 2            KNN_comp_0  Compressor        0  0.489528      0.474152
# 3     GaussianNB_comp_0  Compressor        0  0.352416      0.117932
# 4            SVC_comp_0  Compressor        0  0.331472      0.000000
# 5       AdaBoost_comp_0  Compressor        0  0.592293      0.565428
# 6   DecisionTree_turb_0     Turbina        0  0.735549      0.790414
# 7   RandomForest_turb_0     Turbina        0  0.806199      0.865150
# 8            KNN_turb_0     Turbina        0  0.388160      0.437855
# 9     GaussianNB_turb_0     Turbina        0  0.345434      0.314379
# 10           SVC_turb_0     Turbina        0  0.343759      1.000000
# 11      AdaBoost_turb_0     Turbina        0  0.557665      0.687246
# 12  DecisionTree_comp_1  Compressor        1  0.881597      0.693976
# 13  RandomForest_comp_1  Compressor        1  0.897235      0.759036
# 14           KNN_comp_1  Compressor        1  0.767104      0.144578
# 15    GaussianNB_comp_1  Compressor        1  0.788607      0.002410
# 16           SVC_comp_1  Compressor        1  0.788327      0.000000
# 17      AdaBoost_comp_1  Compressor        1  0.814018      0.212048
# 18  DecisionTree_turb_1     Turbina        1  0.809271      0.541562
# 19  RandomForest_turb_1     Turbina        1  0.827981      0.516373
# 20           KNN_turb_1     Turbina        1  0.728847      0.080605
# 21    GaussianNB_turb_1     Turbina        1  0.770734      0.000000
# 22           SVC_turb_1     Turbina        1  0.770734      0.000000
# 23      AdaBoost_turb_1     Turbina        1  0.773806      0.047859
# 24  DecisionTree_comp_2  Compressor        2  0.892488      0.454545
# 25  RandomForest_comp_2  Compressor        2  0.914828      0.507177
# 26           KNN_comp_2  Compressor        2  0.868193      0.043062
# 27    GaussianNB_comp_2  Compressor        2  0.881039      0.000000
# 28           SVC_comp_2  Compressor        2  0.881039      0.000000
# 29      AdaBoost_comp_2  Compressor        2  0.885786      0.086124
# 30  DecisionTree_turb_2     Turbina        2  0.861770      0.353333
# 31  RandomForest_turb_2     Turbina        2  0.889975      0.190000
# 32           KNN_turb_2     Turbina        2  0.871544      0.030000
# 33    GaussianNB_turb_2     Turbina        2  0.878805      0.000000
# 34           SVC_turb_2     Turbina        2  0.878805      0.000000
# 35      AdaBoost_turb_2     Turbina        2  0.879084      0.030000
#
#     F1-score_Emerg
# 0         0.896386
# 1         0.923445
# 2         0.506908
# 3         0.196369
# 4         0.000000
# 5         0.642497
# 6         0.794286
# 7         0.854392
# 8         0.440180
# 9         0.323038
# 10        0.511638
# 11        0.644817
# 12        0.705018
# 13        0.775862
# 14        0.204778
# 15        0.004808
# 16        0.000000
# 17        0.321168
# 18        0.548469
# 19        0.579096
# 20        0.113074
# 21        0.000000
# 22        0.000000
# 23        0.087760
# 24        0.478589
# 25        0.588889
# 26        0.072000
# 27        0.000000
# 28        0.000000
# 29        0.150628
# 30        0.400756
# 31        0.295337
# 32        0.052941
# 33        0.000000
# 34        0.000000
# 35        0.056426

# %% [markdown]
# ## 5 - Avaliação dos Resultados (Evaluation)

# %% [markdown]
# As métricas utilizadas para avaliação do modelo serão a acurácia total a revocação (recall) da classe 'Emerg'. Isto porque a primeira mede o índice geral de acerto do modelo e a segunda mede o quanto o modelo é sensível para detectar o caso mais crítico, que é quando a manutenção tem que ser executada de maneira emergencial. Um balanço entre as duas é desejável, uma vez que de nada adiantaria um recall de 100% com um modelo que atribuísse 100% das saídas ao status 'Emerg' e estivesse errado em todos os demais casos.
#
# ![recall](img/recall.png)

# %% [markdown]
# ### Cenário 0:

# %%
# Resultados para o compressor
resultados[(resultados['Cenario']==0) & (resultados['Estagio']=='Compressor')].sort_values(by='Recall_Emerg', ascending=False)
# Out:
#                 Modelo     Estagio  Cenario  Acuracia  Recall_Emerg  \
# 1  RandomForest_comp_0  Compressor        0  0.905613      0.935380
# 0  DecisionTree_comp_0  Compressor        0  0.867914      0.901454
# 5      AdaBoost_comp_0  Compressor        0  0.592293      0.565428
# 2           KNN_comp_0  Compressor        0  0.489528      0.474152
# 3    GaussianNB_comp_0  Compressor        0  0.352416      0.117932
# 4           SVC_comp_0  Compressor        0  0.331472      0.000000
#
#    F1-score_Emerg
# 1        0.923445
# 0        0.896386
# 5        0.642497
# 2        0.506908
# 3        0.196369
# 4        0.000000

# %%
# Resultados para a turbina
resultados[(resultados['Cenario']==0) & (resultados['Estagio']=='Turbina')].sort_values(by='Recall_Emerg', ascending=False)
# Out:
#                  Modelo  Estagio  Cenario  Acuracia  Recall_Emerg  \
# 10           SVC_turb_0  Turbina        0  0.343759      1.000000
# 7   RandomForest_turb_0  Turbina        0  0.806199      0.865150
# 6   DecisionTree_turb_0  Turbina        0  0.735549      0.790414
# 11      AdaBoost_turb_0  Turbina        0  0.557665      0.687246
# 8            KNN_turb_0  Turbina        0  0.388160      0.437855
# 9     GaussianNB_turb_0  Turbina        0  0.345434      0.314379
#
#     F1-score_Emerg
# 10        0.511638
# 7         0.854392
# 6         0.794286
# 11        0.644817
# 8         0.440180
# 9         0.323038

# %% [markdown]
# ### Cenário 1:

# %%
# Resultados para o compressor
resultados[(resultados['Cenario']==1) & (resultados['Estagio']=='Compressor')].sort_values(by='Recall_Emerg', ascending=False)
# Out:
#                  Modelo     Estagio  Cenario  Acuracia  Recall_Emerg  \
# 13  RandomForest_comp_1  Compressor        1  0.897235      0.759036
# 12  DecisionTree_comp_1  Compressor        1  0.881597      0.693976
# 17      AdaBoost_comp_1  Compressor        1  0.814018      0.212048
# 14           KNN_comp_1  Compressor        1  0.767104      0.144578
# 15    GaussianNB_comp_1  Compressor        1  0.788607      0.002410
# 16           SVC_comp_1  Compressor        1  0.788327      0.000000
#
#     F1-score_Emerg
# 13        0.775862
# 12        0.705018
# 17        0.321168
# 14        0.204778
# 15        0.004808
# 16        0.000000

# %%
# Resultados para a turbina
resultados[(resultados['Cenario']==1) & (resultados['Estagio']=='Turbina')].sort_values(by='Recall_Emerg', ascending=False)
# Out:
#                  Modelo  Estagio  Cenario  Acuracia  Recall_Emerg  \
# 18  DecisionTree_turb_1  Turbina        1  0.809271      0.541562
# 19  RandomForest_turb_1  Turbina        1  0.827981      0.516373
# 20           KNN_turb_1  Turbina        1  0.728847      0.080605
# 23      AdaBoost_turb_1  Turbina        1  0.773806      0.047859
# 21    GaussianNB_turb_1  Turbina        1  0.770734      0.000000
# 22           SVC_turb_1  Turbina        1  0.770734      0.000000
#
#     F1-score_Emerg
# 18        0.548469
# 19        0.579096
# 20        0.113074
# 23        0.087760
# 21        0.000000
# 22        0.000000

# %% [markdown]
# ### Cenário 2:

# %%
# Resultados para o compressor
resultados[(resultados['Cenario']==2) & (resultados['Estagio']=='Compressor')].sort_values(by='Recall_Emerg', ascending=False)
# Out:
#                  Modelo     Estagio  Cenario  Acuracia  Recall_Emerg  \
# 25  RandomForest_comp_2  Compressor        2  0.914828      0.507177
# 24  DecisionTree_comp_2  Compressor        2  0.892488      0.454545
# 29      AdaBoost_comp_2  Compressor        2  0.885786      0.086124
# 26           KNN_comp_2  Compressor        2  0.868193      0.043062
# 27    GaussianNB_comp_2  Compressor        2  0.881039      0.000000
# 28           SVC_comp_2  Compressor        2  0.881039      0.000000
#
#     F1-score_Emerg
# 25        0.588889
# 24        0.478589
# 29        0.150628
# 26        0.072000
# 27        0.000000
# 28        0.000000

# %%
# Resultados para a turbina
resultados[(resultados['Cenario']==2) & (resultados['Estagio']=='Turbina')].sort_values(by='Recall_Emerg', ascending=False)
# Out:
#                  Modelo  Estagio  Cenario  Acuracia  Recall_Emerg  \
# 30  DecisionTree_turb_2  Turbina        2  0.861770      0.353333
# 31  RandomForest_turb_2  Turbina        2  0.889975      0.190000
# 32           KNN_turb_2  Turbina        2  0.871544      0.030000
# 35      AdaBoost_turb_2  Turbina        2  0.879084      0.030000
# 33    GaussianNB_turb_2  Turbina        2  0.878805      0.000000
# 34           SVC_turb_2  Turbina        2  0.878805      0.000000
#
#     F1-score_Emerg
# 30        0.400756
# 31        0.295337
# 32        0.052941
# 35        0.056426
# 33        0.000000
# 34        0.000000

# %% [markdown]
# ## Definição de modelos e cenário para otimização dos hiperparâmetros
# Arbitrariamente definido que será escolhido o cenário 1, modelos RandomForest_comp_1 para o compressor (Recall_Emerg 0.759036) e DecisionTree_turb_1 para turbina (Recall_Emerg  0.541562). Estes modelos apresentaram os maiores recalls da categoria Emergência para o seu cenário, ainda com margem para otimizações.

# %%
from sklearn.model_selection import GridSearchCV

# %%
modelos[2]['RandomForest_comp_1']
# Out:
# RandomForestClassifier()

# %%
modelos[3]['DecisionTree_turb_1']
# Out:
# DecisionTreeClassifier()

# %%
RF = RandomForestClassifier()

# %%
RF_param = {
    'n_estimators': [50, 100, 300, 500],
    'criterion': ["gini", "entropy"],
    'max_depth': [None, 5, 10],
    'min_samples_split': [2, 4, 8]
}

# %%
RF_otimizado = GridSearchCV(RF, RF_param, cv=10, scoring='f1_macro', n_jobs=4, verbose=3)

# %%
# %%time
RF_otimizado.fit(conj_treino_teste[2][0], conj_treino_teste[2][2])
# Out:
# Fitting 10 folds for each of 72 candidates, totalling 720 fits
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  24 tasks      | elapsed:   26.5s
# [Parallel(n_jobs=4)]: Done 120 tasks      | elapsed:  4.3min
# [Parallel(n_jobs=4)]: Done 280 tasks      | elapsed:  7.4min
# [Parallel(n_jobs=4)]: Done 504 tasks      | elapsed: 17.1min
# [Parallel(n_jobs=4)]: Done 720 out of 720 | elapsed: 25.0min finished
# CPU times: user 13.8 s, sys: 412 ms, total: 14.2 s
# Wall time: 25min 14s
# GridSearchCV(cv=10, estimator=RandomForestClassifier(), n_jobs=4,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [None, 5, 10],
#                          'min_samples_split': [2, 4, 8],
#                          'n_estimators': [50, 100, 300, 500]},
#              scoring='f1_macro', verbose=3)

# %%
conj_treino_teste[2][0]
# Out:
#           lp          v           GTT          GTn          GGn          Ts  \
# 3904   8.206  24.142363  51133.502695  3087.697243  9228.928975  439.713403
# 3277   2.088   5.895312   4653.191647  1364.092534  6748.725336   22.097354
# 8161   8.206  24.262539  50994.136945  3070.516083  9254.413784  437.895057
# 9015   7.148  21.539413  39213.156640  2658.543138  9146.556725  332.235953
# 9018   1.138   2.964744   1100.419435  1365.341729  6746.741775   12.006794
# ...      ...        ...           ...          ...          ...         ...
# 6000   7.148  21.967374  38784.442598  2693.141805  9133.870429  333.653274
# 5309   9.300  26.345399  72564.440508  3542.464234  9735.071951  644.491112
# 11326  5.140  16.028337  21220.046518  1912.091786  8401.648675  173.824023
# 10427  6.175  18.211221  29693.997206  2307.295141  8968.256834  246.317068
# 1817   9.300  27.979531  72380.820815  3559.199435  9852.789610  647.554045
#
#                Tp          T48          T2       P48         P2      Pexh  \
# 3904   437.628323   923.364108  733.798383  3.581915  18.519159  1.044542
# 3277    23.441287   572.714669  569.068334  1.229480   6.873288  1.019942
# 8161   437.936225   906.550024  727.361929  3.572745  18.491325  1.048840
# 9015   334.348286   815.815727  685.843331  2.963531  15.640506  1.031360
# 9018     7.588672   469.006305  546.592473  1.163110   6.104456  1.009911
# ...           ...          ...         ...       ...        ...       ...
# 6000   327.271510   821.310448  689.323287  2.957004  15.511454  1.038855
# 5309   644.792577  1075.328638  778.537388  4.507552  22.484251  1.052655
# 11326  178.022437   696.695747  632.029978  2.091280  11.115640  1.023891
# 10427  247.863126   761.990359  662.675640  2.527785  13.133043  1.033898
# 1817   644.804325  1090.873911  783.812294  4.501750  22.306320  1.054722
#
#           TIC        mf
# 3904   60.161  1.190758
# 3277   24.131  0.232769
# 8161   58.971  1.187408
# 9015   43.472  0.872432
# 9018    2.824  0.100329
# ...       ...       ...
# 6000   43.688  0.880426
# 5309   89.032  1.762499
# 11326  24.671  0.499859
# 10427  33.601  0.659458
# 1817   90.010  1.773171
#
# [8353 rows x 14 columns]

# %%
conj_treino_teste[2][2]
# Out:
# 3904     Normal
# 3277     Normal
# 8161     Normal
# 9015     Normal
# 9018     Normal
#           ...
# 6000     Normal
# 5309     Normal
# 11326    Normal
# 10427    Normal
# 1817      Alert
# Name: status_c_1, Length: 8353, dtype: category
# Categories (3, object): ['Emerg' < 'Alert' < 'Normal']

# %%
conj_treino_teste[2]
# Out:
# [          lp          v           GTT          GTn          GGn          Ts  \
#  3904   8.206  24.142363  51133.502695  3087.697243  9228.928975  439.713403
#  3277   2.088   5.895312   4653.191647  1364.092534  6748.725336   22.097354
#  8161   8.206  24.262539  50994.136945  3070.516083  9254.413784  437.895057
#  9015   7.148  21.539413  39213.156640  2658.543138  9146.556725  332.235953
#  9018   1.138   2.964744   1100.419435  1365.341729  6746.741775   12.006794
#  ...      ...        ...           ...          ...          ...         ...
#  6000   7.148  21.967374  38784.442598  2693.141805  9133.870429  333.653274
#  5309   9.300  26.345399  72564.440508  3542.464234  9735.071951  644.491112
#  11326  5.140  16.028337  21220.046518  1912.091786  8401.648675  173.824023
#  10427  6.175  18.211221  29693.997206  2307.295141  8968.256834  246.317068
#  1817   9.300  27.979531  72380.820815  3559.199435  9852.789610  647.554045
#
#                 Tp          T48          T2       P48         P2      Pexh  \
#  3904   437.628323   923.364108  733.798383  3.581915  18.519159  1.044542
#  3277    23.441287   572.714669  569.068334  1.229480   6.873288  1.019942
#  8161   437.936225   906.550024  727.361929  3.572745  18.491325  1.048840
#  9015   334.348286   815.815727  685.843331  2.963531  15.640506  1.031360
#  9018     7.588672   469.006305  546.592473  1.163110   6.104456  1.009911
#  ...           ...          ...         ...       ...        ...       ...
#  6000   327.271510   821.310448  689.323287  2.957004  15.511454  1.038855
#  5309   644.792577  1075.328638  778.537388  4.507552  22.484251  1.052655
#  11326  178.022437   696.695747  632.029978  2.091280  11.115640  1.023891
#  10427  247.863126   761.990359  662.675640  2.527785  13.133043  1.033898
#  1817   644.804325  1090.873911  783.812294  4.501750  22.306320  1.054722
#
#            TIC        mf
#  3904   60.161  1.190758
#  3277   24.131  0.232769
#  8161   58.971  1.187408
#  9015   43.472  0.872432
#  9018    2.824  0.100329
#  ...       ...       ...
#  6000   43.688  0.880426
#  5309   89.032  1.762499
#  11326  24.671  0.499859
#  10427  33.601  0.659458
#  1817   90.010  1.773171
#
#  [8353 rows x 14 columns],
#            lp          v           GTT          GTn          GGn          Ts  \
#  8041   5.140  16.081447  21848.744003  1954.725977  8388.312828  176.477384
#  2083   5.140  14.349342  21640.544198  1915.661066  8524.298158  176.197276
#  2177   9.300  27.160436  72805.712931  3548.508657  9765.091500  641.837983
#  9281   3.144   7.667970   8204.167228  1385.538372  7080.872211   59.992473
#  11246  6.175  17.657841  30065.026330  2307.427771  8880.947620  245.579072
#  ...      ...        ...           ...          ...          ...         ...
#  11630  3.144   9.558666   8283.504320  1360.624259  7019.668724   58.378536
#  5343   7.148  20.485861  39365.967765  2709.601059  9172.685776  329.364936
#  4670   9.300  27.028438  73062.615080  3592.039719  9796.375108  642.944743
#  1256   6.175  17.547612  29694.672784  2294.268967  8799.911033  246.131634
#  8502   7.148  21.037077  38764.495824  2686.847275  9049.756699  330.836240
#
#                 Tp          T48          T2       P48         P2      Pexh  \
#  8041   177.732018   704.721561  635.646796  2.115307  10.854373  1.038977
#  2083   176.430742   704.960919  639.463540  2.095631  11.093689  1.027177
#  2177   646.679179  1098.936787  784.789561  4.508984  22.706169  1.038692
#  9281    61.035248   574.589884  576.784997  1.391104   7.439310  1.018722
#  11246  247.586114   774.168503  664.551488  2.506747  13.390371  1.045183
#  ...           ...          ...         ...       ...        ...       ...
#  11630   60.922192   569.640479  574.531977  1.368475   7.396646  1.011651
#  5343   333.256517   818.266010  689.463851  2.930554  15.274476  1.045861
#  4670   644.706262  1073.009077  778.794844  4.508403  22.235611  1.053272
#  1256   246.179160   787.631219  673.178092  2.479790  13.196850  1.024424
#  8502   330.963127   822.255581  687.465268  2.999247  15.790049  1.018900
#
#            TIC        mf
#  8041   25.053  0.509781
#  2083   24.900  0.497985
#  2177   91.101  1.803802
#  9281   11.860  0.234199
#  11246  34.448  0.688483
#  ...       ...       ...
#  11630  11.665  0.225599
#  5343   43.397  0.872681
#  4670   88.547  1.763268
#  1256   34.973  0.692827
#  8502   43.946  0.884770
#
#  [3581 rows x 14 columns],
#  3904     Normal
#  3277     Normal
#  8161     Normal
#  9015     Normal
#  9018     Normal
#            ...
#  6000     Normal
#  5309     Normal
#  11326    Normal
#  10427    Normal
#  1817      Alert
#  Name: status_c_1, Length: 8353, dtype: category
#  Categories (3, object): ['Emerg' < 'Alert' < 'Normal'],
#  8041     Normal
#  2083      Alert
#  2177      Alert
#  9281     Normal
#  11246    Normal
#            ...
#  11630    Normal
#  5343     Normal
#  4670     Normal
#  1256      Emerg
#  8502     Normal
#  Name: status_c_1, Length: 3581, dtype: category
#  Categories (3, object): ['Emerg' < 'Alert' < 'Normal']]

# %%
conj_treino_teste[3]
# Out:
# [          lp          v           GTT          GTn          GGn          Ts  \
#  7649   9.300  27.491333  72744.755284  3547.970775  9846.946774  645.443929
#  6874   8.206  24.046705  51005.022031  3075.237828  9374.744165  438.445200
#  11760  7.148  20.955021  39134.438127  2653.935725  9170.415665  331.585092
#  2991   4.161  11.339912  14677.280080  1560.293345  7762.529804  114.624984
#  8465   6.175  17.663370  29816.504790  2300.197763  8901.857315  247.944612
#  ...      ...        ...           ...          ...          ...         ...
#  2125   2.088   5.979252   5297.821283  1340.835311  6959.805266   21.716511
#  6115   5.140  15.516919  21612.559462  1910.894592  8654.474370  173.464828
#  1585   2.088   5.919874   3363.206456  1350.624936  6788.174837   19.709125
#  8697   4.161  10.722101  14631.523355  1538.667653  7703.351248  114.812456
#  6540   7.148  20.811875  38897.892958  2683.706683  9281.141014  331.860039
#
#                 Tp          T48          T2       P48         P2      Pexh  \
#  7649   647.722841  1064.443285  774.994253  4.509914  22.363090  1.064006
#  6874   441.060267   923.121925  731.085314  3.615313  18.535724  1.035721
#  11760  330.842874   815.416886  683.657764  3.000046  15.471241  1.036270
#  2991   111.832846   638.407895  607.990852  1.699542   8.979637  1.016631
#  8465   247.561669   776.976133  666.641993  2.549373  13.399644  1.032736
#  ...           ...          ...         ...       ...        ...       ...
#  2125    23.815195   600.041749  573.816563  1.283727   7.103797  1.033912
#  6115   175.575002   714.754841  638.556672  2.084350  11.173834  1.025603
#  1585    25.841516   527.481686  563.078360  1.213495   6.547796  1.016556
#  8697   113.095578   640.823637  605.166208  1.641270   9.259532  1.017195
#  6540   331.760127   812.106252  687.473764  2.979886  15.179318  1.043134
#
#            TIC        mf
#  7649   88.257  1.748954
#  6874   60.422  1.194198
#  11760  43.626  0.866655
#  2991   17.042  0.335116
#  8465   34.525  0.685757
#  ...       ...       ...
#  2125   23.647  0.254537
#  6115   25.579  0.510708
#  1585   19.307  0.159798
#  8697   17.261  0.339765
#  6540   42.984  0.862003
#
#  [8353 rows x 14 columns],
#            lp          v           GTT          GTn          GGn          Ts  \
#  291    4.161  11.513734  14556.863338  1595.751103  7938.032750  112.343414
#  6592   5.140  15.259036  21787.175570  1938.671378  8465.283830  177.625893
#  9401   6.175  18.322276  29726.103134  2324.480032  8841.324814  247.655040
#  2513   3.144   9.122458   8238.881167  1412.249829  7038.436387   62.780323
#  9163   2.088   6.763933   5219.816125  1414.250946  6747.221807   31.893426
#  ...      ...        ...           ...          ...          ...         ...
#  11756  3.144   8.789327   8239.416516  1383.015468  7020.248161   61.683537
#  10242  1.138   2.629480   2538.372586  1358.226046  6628.859470   12.085339
#  7754   6.175  19.079066  29530.857477  2317.466580  8760.545793  246.624465
#  3959   9.300  26.682698  72788.489788  3560.528715  9845.902625  647.644170
#  4400   9.300  26.613008  72989.873592  3531.162226  9823.482168  646.245648
#
#                 Tp          T48          T2       P48         P2      Pexh  \
#  291    113.273590   655.619376  612.672649  1.643375   9.042402  1.039333
#  6592   178.387574   712.600895  637.943696  2.046502  11.123549  0.995219
#  9401   244.840903   774.942058  665.704261  2.497713  13.456275  1.041987
#  2513    59.013279   585.970551  582.460547  1.355274   7.422218  1.011355
#  9163    31.907797   559.947249  566.546643  1.316629   6.748151  1.031887
#  ...           ...          ...         ...       ...        ...       ...
#  11756   57.791983   578.606537  575.982394  1.387326   7.915469  1.035026
#  10242   12.566871   502.539309  552.687944  1.182845   6.366137  1.012237
#  7754   246.268185   779.663538  667.648198  2.497817  13.323750  1.038417
#  3959   647.608093  1077.085052  779.957793  4.470727  22.239987  1.050830
#  4400   645.783299  1077.401506  779.584204  4.449206  22.429743  1.066172
#
#            TIC        mf
#  291    17.833  0.334427
#  6592   25.475  0.489627
#  9401   34.425  0.686646
#  2513   12.275  0.240361
#  9163    0.000  0.202204
#  ...       ...       ...
#  11756  12.047  0.224219
#  10242   0.086  0.140259
#  7754   34.673  0.668383
#  3959   88.885  1.768663
#  4400   89.035  1.771369
#
#  [3581 rows x 14 columns],
#  7649     Normal
#  6874     Normal
#  11760    Normal
#  2991     Normal
#  8465      Alert
#            ...
#  2125      Emerg
#  6115      Alert
#  1585     Normal
#  8697      Alert
#  6540     Normal
#  Name: status_t_1, Length: 8353, dtype: category
#  Categories (3, object): ['Emerg' < 'Alert' < 'Normal'],
#  291      Normal
#  6592      Alert
#  9401      Alert
#  2513     Normal
#  9163      Alert
#            ...
#  11756    Normal
#  10242    Normal
#  7754      Alert
#  3959     Normal
#  4400     Normal
#  Name: status_t_1, Length: 3581, dtype: category
#  Categories (3, object): ['Emerg' < 'Alert' < 'Normal']]
