# %% [markdown]
# # Manutenção Preditiva (PHM) - Sistema de Propulsão Naval
#
# Rafael Schena
#
# Edit: Alteração dos gatilhos de target para os estados de Emergência, Alerta e Normal, adicionando mais 2 cenários para as proporções de estados dos equipamentos: (10% Emerg, 10% Alert, 80% Normal) e (5% Emerg, 5% Alert e 90% Normal) para observação do desempenho dos algoritmos.

# %% [markdown]
# ## Metodologia
#
# Foi utilizada neste trabalho a metodologia CRISP-DM (CRoss-Industry Standard Process for Data Mining)
# ![crisp-dm](img/crisp-dm.png)
#
# Fases:
# 1. Business understanding – What does the business need?
# 2. Data understanding – What data do we have / need? Is it clean?
# 3. Data preparation – How do we organize the data for modeling?
# 4. Modeling – What modeling techniques should we apply?
# 5. Evaluation – Which model best meets the business objectives?
# 6. Deployment – How do stakeholders access the results?
#
# (https://www.datascience-pm.com/crisp-dm-2/)

# %% [markdown]
# ## 1 - Compreensão do problema de negócio (Business Understanding)
# Este trabalho tem como objetivo principal a mineração de padrões em dados de manutenção preditiva (PHM - Predictive Health Monitoring) em um sistema de propulsão naval. O dataset utilizado foi disponibilizado é um dataset simulado em um modelo de um sistema de propulsão naval de uma fragata que utiliza uma turbina a gás como motor. O dataset foi disponibilizado pelos autores (M Altosole, G Benvenuto, M Figari, and U Campora) no repositório da UCI: http://archive.ics.uci.edu/ml/datasets/condition+based+maintenance+of+naval+propulsion+plants

# %% [markdown]
# Fragata:
# ![fragata](img/frigate.png)

# %% [markdown]
# Sistema de propulsão:
# ![propulsao](img/propulsion.png)
# https://navalpost.com/propulsion-systems-navies-gas-diesel-electric/
#
# Turbina a Gás (Termo mais correto: motor a reação):
# ![turbina](img/gas_turbine.png)
# https://www.geaviation.com/sites/default/files/ge-marine-gas-turbines-for-frigates-2018-march.pdf
#
# ![mecanismo](img/turbine_mechanism.gif)

# %% [markdown]
# ## Definição do problema de negócio (!!!)
# O dataset não define o que caracteriza ou não uma falha no sistema de propulsão da fragata, apenas apresenta os índices de degradação dos estágios de compressão e da turbina. **Níveis de alerta de degradação serão definidos com base na distribuição dos índices de degradação do compressor (kMc) e da turbina (kMt).** Antes disso, será necessária uma melhor compreensão dos dados.
#
# Dicionário de dados:
# - 1 - Lever position (lp) [ ]
# - 2 - Ship speed (v) [knots]
# - 3 - Gas Turbine shaft torque (GTT) [kN m]
# - 4 - Gas Turbine rate of revolutions (GTn) [rpm]
# - 5 - Gas Generator rate of revolutions (GGn) [rpm]
# - 6 - Starboard Propeller Torque (Ts) [kN]
# - 7 - Port Propeller Torque (Tp) [kN]
# - 8 - HP Turbine exit temperature (T48) [C]
# - 9 - GT Compressor inlet air temperature (T1) [C]
# - 10 - GT Compressor outlet air temperature (T2) [C]
# - 11 - HP Turbine exit pressure (P48) [bar]
# - 12 - GT Compressor inlet air pressure (P1) [bar]
# - 13 - GT Compressor outlet air pressure (P2) [bar]
# - 14 - Gas Turbine exhaust gas pressure (Pexh) [bar]
# - 15 - Turbine Injecton Control (TIC) [%]
# - 16 - Fuel flow (mf) [kg/s]
# - 17 - GT Compressor decay state coefficient (kMc).
# - 18 - GT Turbine decay state coefficient (kMt).

# %% [markdown]
# ## 2 - Compreensão dos dados (Data Understanding)

# %%
import pandas as pd
import numpy as np

# %%
features = [
    'lp',
    'v',
    'GTT',
    'GTn',
    'GGn',
    'Ts',
    'Tp',
    'T48',
    'T1',
    'T2',
    'P48',
    'P1',
    'P2',
    'Pexh',
    'TIC',
    'mf',
    'kMc',
    'kMt'
]

# %%
df = pd.read_csv('./data/data.txt', sep='   ', names=features, engine='python')

# %%
df.head()
# Out:
#       lp     v        GTT       GTn       GGn       Ts       Tp      T48  \
# 0  1.138   3.0    289.964  1349.489  6677.380    7.584    7.584  464.006
# 1  2.088   6.0   6960.180  1376.166  6828.469   28.204   28.204  635.401
# 2  3.144   9.0   8379.229  1386.757  7111.811   60.358   60.358  606.002
# 3  4.161  12.0  14724.395  1547.465  7792.630  113.774  113.774  661.471
# 4  5.140  15.0  21636.432  1924.313  8494.777  175.306  175.306  731.494
#
#       T1       T2    P48     P1      P2   Pexh     TIC     mf   kMc    kMt
# 0  288.0  550.563  1.096  0.998   5.947  1.019   7.137  0.082  0.95  0.975
# 1  288.0  581.658  1.331  0.998   7.282  1.019  10.655  0.287  0.95  0.975
# 2  288.0  587.587  1.389  0.998   7.574  1.020  13.086  0.259  0.95  0.975
# 3  288.0  613.851  1.658  0.998   9.007  1.022  18.109  0.358  0.95  0.975
# 4  288.0  645.642  2.078  0.998  11.197  1.026  26.373  0.522  0.95  0.975

# %%
df.shape
# Out:
# (11934, 18)

# %% [markdown]
# ### Verificação valores faltantes e tipos de dados

# %%
# Não há valores faltantes, todas as variáveis são numéricas do tipo float64
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11934 entries, 0 to 11933
# Data columns (total 18 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   lp      11934 non-null  float64
#  1   v       11934 non-null  float64
#  2   GTT     11934 non-null  float64
#  3   GTn     11934 non-null  float64
#  4   GGn     11934 non-null  float64
#  5   Ts      11934 non-null  float64
#  6   Tp      11934 non-null  float64
#  7   T48     11934 non-null  float64
#  8   T1      11934 non-null  float64
#  9   T2      11934 non-null  float64
#  10  P48     11934 non-null  float64
#  11  P1      11934 non-null  float64
#  12  P2      11934 non-null  float64
#  13  Pexh    11934 non-null  float64
#  14  TIC     11934 non-null  float64
#  15  mf      11934 non-null  float64
#  16  kMc     11934 non-null  float64
#  17  kMt     11934 non-null  float64
# dtypes: float64(18)
# memory usage: 1.6 MB

# %% [markdown]
# ### Estatísticas das features numéricas

# %%
df.describe()
# Out:
#                  lp             v           GTT           GTn           GGn  \
# count  11934.000000  11934.000000  11934.000000  11934.000000  11934.000000
# mean       5.166667     15.000000  27247.498685   2136.289256   8200.947312
# std        2.626388      7.746291  22148.613155    774.083881   1091.315507
# min        1.138000      3.000000    253.547000   1307.675000   6589.002000
# 25%        3.144000      9.000000   8375.883750   1386.758000   7058.324000
# 50%        5.140000     15.000000  21630.659000   1924.326000   8482.081500
# 75%        7.148000     21.000000  39001.426750   2678.079000   9132.606000
# max        9.300000     27.000000  72784.872000   3560.741000   9797.103000
#
#                  Ts            Tp           T48       T1            T2  \
# count  11934.000000  11934.000000  11934.000000  11934.0  11934.000000
# mean     227.335768    227.335768    735.495446    288.0    646.215331
# std      200.495889    200.495889    173.680552      0.0     72.675882
# min        5.304000      5.304000    442.364000    288.0    540.442000
# 25%       60.317000     60.317000    589.872750    288.0    578.092250
# 50%      175.268000    175.268000    706.038000    288.0    637.141500
# 75%      332.364750    332.364750    834.066250    288.0    693.924500
# max      645.249000    645.249000   1115.797000    288.0    789.094000
#
#                 P48            P1            P2          Pexh           TIC  \
# count  11934.000000  1.193400e+04  11934.000000  11934.000000  11934.000000
# mean       2.352963  9.980000e-01     12.297123      1.029474     33.641261
# std        1.084770  2.533635e-13      5.337448      0.010390     25.841363
# min        1.093000  9.980000e-01      5.828000      1.019000      0.000000
# 25%        1.389000  9.980000e-01      7.447250      1.020000     13.677500
# 50%        2.083000  9.980000e-01     11.092000      1.026000     25.276500
# 75%        2.981000  9.980000e-01     15.658000      1.036000     44.552500
# max        4.560000  9.980000e-01     23.140000      1.052000     92.556000
#
#                  mf          kMc         kMt
# count  11934.000000  11934.00000  11934.0000
# mean       0.662440      0.97500      0.9875
# std        0.507132      0.01472      0.0075
# min        0.068000      0.95000      0.9750
# 25%        0.246000      0.96200      0.9810
# 50%        0.496000      0.97500      0.9875
# 75%        0.882000      0.98800      0.9940
# max        1.832000      1.00000      1.0000

# %%
for col in df.columns:
    print(f'Valores únicos de {col}: {len(df[col].unique())}')
# Out:
# Valores únicos de lp: 9
# Valores únicos de v: 9
# Valores únicos de GTT: 11430
# Valores únicos de GTn: 3888
# Valores únicos de GGn: 11834
# Valores únicos de Ts: 4286
# Valores únicos de Tp: 4286
# Valores únicos de T48: 11772
# Valores únicos de T1: 1
# Valores únicos de T2: 11506
# Valores únicos de P48: 524
# Valores únicos de P1: 1
# Valores únicos de P2: 4209
# Valores únicos de Pexh: 19
# Valores únicos de TIC: 8496
# Valores únicos de mf: 696
# Valores únicos de kMc: 51
# Valores únicos de kMt: 26

# %% [markdown]
# ### Verificando a presença de outliers nos dados

# %%
import matplotlib.pyplot as plt

# %%
fig, ax_matrix = plt.subplots(6, 3, figsize=(20, 20));

# Atribuir um subgráfico para cada feature
mapeamento = {}
for (i, f) in enumerate(features):
    mapeamento[f] = ax_matrix[i//3][i%3]

for feat in features:
    mapeamento[feat].set_title(f'Boxplot {feat}')
    mapeamento[feat].boxplot(df[feat])
    
plt.show()

# %% [markdown]
# ### Constatações:
# - As features T1 e P1 não apresentam variabilidade e podem ser eliminadas do dataset, porque não contribuem para a previsibilidade das variáveis target;
# - A feature TIC apresenta outliers que merecem ser investigados mais a fundo;

# %% [markdown]
# ## Verificação da distribuição dos dados

# %%
fig, ax_matrix = plt.subplots(6, 3, figsize=(20, 20));

# Atribuir um subgráfico para cada feature
mapeamento = {}
for (i, f) in enumerate(features):
    mapeamento[f] = ax_matrix[i//3][i%3]

for feat in features:
    mapeamento[feat].set_title(f'Histograma {feat}')
    mapeamento[feat].hist(df[feat], bins=30)
    
plt.show()

# %% [markdown]
# ### Constatações
# - Os dados não se apresentam na forma de séries temporais, uma vez que não têm associado um timestamp e nenhuma indicação de que estão em uma sequência no tempo;
# - Na distribuição estatística dos dados (histogramas) podem ser verificados muitos gaps, indicando que existem faixas de valores que não constam no conjunto de dados, apesar de se tratar de um dataset composto somente por variáveis contínuas. Tal característica da distribuição dos dados permite que se efetue uma discretização destas grandezas com uma menor perda de informação (erro de quantização). Isto sugere que pode ser interessante a criação de novas features a partir da discretização das features originais.
# - Faixas de variação muito diferentes entre as features;
# - Os outliers da feature TIC representam os valores acima de 80% da capacidade de injeção de combustível na turbina. Representam os casos em que a fragata demandou uma aceleração maior e somam cerca de 1200 observações no dataset (aproximadamente 10% das observações). Decidiu-se por manter estes valores por representarem situações de operação normal do equipamento.

# %% [markdown]
# ## (!!!) Definição do problema de negócio com base nos dados
# Para os targets kMc e kMt fica **arbitrariamente** definido:
#
# Cenário 0:
# - **Emergência**: faixa de 33% piores valores possíveis para o range observado;
# - **Alerta**: faixa entre 33% e 66% piores valores possíveis para o range observado;
# - **Normal**: faixa de 33% melhores valores possíveis para o range observado.
#
# Cenário 1:
# - **Emergência**: faixa de 10% piores valores possíveis para o range observado;
# - **Alerta**: faixa entre 10% e 20% piores valores possíveis para o range observado;
# - **Normal**: faixa de 80% melhores valores possíveis para o range observado.
#
# Cenário 2:
# - **Emergência**: faixa de 5% piores valores possíveis para o range observado;
# - **Alerta**: faixa entre 5% e 10% piores valores possíveis para o range observado;
# - **Normal**: faixa de 90% melhores valores possíveis para o range observado.

# %%
range_kMc = df['kMc'].max() - df['kMc'].min()

# %%
# Proporções percentuais para os cenários 0, 1 e 2, respectivamente, como tuplas na lista proporções
cenarios = [(0.33, 0.66),
             (0.1, 0.2),
             (0.05, 0.1)]

# %%
# Lista com os valores limites de kMc para alerta e emergência para os três cenários
lim_comp = []

for c in cenarios:
    lim = {}
    lim['emerg'] = df['kMc'].min() + c[0]*range_kMc
    lim['alert'] = df['kMc'].min() + c[1]*range_kMc
    lim_comp.append(lim)

# %%
for k in range(len(lim_comp)):
    print(f'Níveis de emergência e alerta de kMc para o cenário {k}: {lim_comp[k]}')
# Out:
# Níveis de emergência e alerta de kMc para o cenário 0: {'emerg': 0.9664999999999999, 'alert': 0.983}
# Níveis de emergência e alerta de kMc para o cenário 1: {'emerg': 0.955, 'alert': 0.96}
# Níveis de emergência e alerta de kMc para o cenário 2: {'emerg': 0.9524999999999999, 'alert': 0.955}

# %%
# Lista com os valores limites de kMc para alerta e emergência para os três cenários
range_kMt = df['kMt'].max() - df['kMt'].min()
lim_turb = []

for c in cenarios:
    lim = {}
    lim['emerg'] = df['kMt'].min() + c[0]*range_kMt
    lim['alert'] = df['kMt'].min() + c[1]*range_kMt
    lim_turb.append(lim)

# %%
for k in range(len(lim_turb)):
    print(f'Níveis de emergência e alerta de kMt para o cenário {k}: {lim_turb[k]}')
# Out:
# Níveis de emergência e alerta de kMt para o cenário 0: {'emerg': 0.98325, 'alert': 0.9915}
# Níveis de emergência e alerta de kMt para o cenário 1: {'emerg': 0.9775, 'alert': 0.98}
# Níveis de emergência e alerta de kMt para o cenário 2: {'emerg': 0.97625, 'alert': 0.9775}

# %%
for k in range(len(cenarios)):
    fig, ax = plt.subplots(1, 2, figsize=(16, 4))
    fig.suptitle(f'Cenário {k}')
    
    ax[0].set_title(f'Histograma kMc')
    ax[0].axvline(lim_comp[k]['alert'], color='orange', lw=2, alpha=1)
    ax[0].axvline(lim_comp[k]['emerg'], color='red', lw=2, alpha=1)
    ax[0].hist(df['kMc'], bins=30, alpha = 0.3);

    ax[1].set_title(f'Histograma kMt')
    ax[1].axvline(lim_turb[k]['alert'], color='orange', lw=2, alpha=1)
    ax[1].axvline(lim_turb[k]['emerg'], color='red', lw=2, alpha=1)
    ax[1].hist(df['kMt'], bins=30, alpha = 0.3);

# %% [markdown]
# ### Exclusão das features que não acrescentam informação ao dataset:

# %%
# Excluindo as features que não apresentam variabilidade
df.drop(columns=['T1', 'P1'], inplace=True)
features = df.columns
df.head()
# Out:
#       lp     v        GTT       GTn       GGn       Ts       Tp      T48  \
# 0  1.138   3.0    289.964  1349.489  6677.380    7.584    7.584  464.006
# 1  2.088   6.0   6960.180  1376.166  6828.469   28.204   28.204  635.401
# 2  3.144   9.0   8379.229  1386.757  7111.811   60.358   60.358  606.002
# 3  4.161  12.0  14724.395  1547.465  7792.630  113.774  113.774  661.471
# 4  5.140  15.0  21636.432  1924.313  8494.777  175.306  175.306  731.494
#
#         T2    P48      P2   Pexh     TIC     mf   kMc    kMt
# 0  550.563  1.096   5.947  1.019   7.137  0.082  0.95  0.975
# 1  581.658  1.331   7.282  1.019  10.655  0.287  0.95  0.975
# 2  587.587  1.389   7.574  1.020  13.086  0.259  0.95  0.975
# 3  613.851  1.658   9.007  1.022  18.109  0.358  0.95  0.975
# 4  645.642  2.078  11.197  1.026  26.373  0.522  0.95  0.975

# %%
type(lim_comp[k]['emerg'])
# Out:
# float

# %% [markdown]
# ### Criação dos labels das variáveis target

# %%
# status_c é o status do compressor, podendo assumir valores 'Emerg', 'Alert', 'Normal'
df['status_c_0'] = pd.cut(df['kMc'], bins=[0, lim_comp[0]['emerg'], lim_comp[0]['alert'], float('Inf')], labels=['Emerg', 'Alert', 'Normal'])
# status_t é o status do compressor, podendo assumir valores 'Emerg', 'Alert', 'Normal'
df['status_t_0'] = pd.cut(df['kMt'], bins=[0, lim_turb[0]['emerg'], lim_turb[0]['alert'], float('Inf')], labels=['Emerg', 'Alert', 'Normal'])

df['status_c_1'] = pd.cut(df['kMc'], bins=[0, lim_comp[1]['emerg'], lim_comp[1]['alert'], float('Inf')], labels=['Emerg', 'Alert', 'Normal'])
df['status_t_1'] = pd.cut(df['kMt'], bins=[0, lim_turb[1]['emerg'], lim_turb[1]['alert'], float('Inf')], labels=['Emerg', 'Alert', 'Normal'])

df['status_c_2'] = pd.cut(df['kMc'], bins=[0, lim_comp[2]['emerg'], lim_comp[2]['alert'], float('Inf')], labels=['Emerg', 'Alert', 'Normal'])
df['status_t_2'] = pd.cut(df['kMt'], bins=[0, lim_turb[2]['emerg'], lim_turb[2]['alert'], float('Inf')], labels=['Emerg', 'Alert', 'Normal'])

# %%
df
# Out:
#           lp     v        GTT       GTn       GGn       Ts       Tp       T48  \
# 0      1.138   3.0    289.964  1349.489  6677.380    7.584    7.584   464.006
# 1      2.088   6.0   6960.180  1376.166  6828.469   28.204   28.204   635.401
# 2      3.144   9.0   8379.229  1386.757  7111.811   60.358   60.358   606.002
# 3      4.161  12.0  14724.395  1547.465  7792.630  113.774  113.774   661.471
# 4      5.140  15.0  21636.432  1924.313  8494.777  175.306  175.306   731.494
# ...      ...   ...        ...       ...       ...      ...      ...       ...
# 11929  5.140  15.0  21624.934  1924.342  8470.013  175.239  175.239   681.658
# 11930  6.175  18.0  29763.213  2306.745  8800.352  245.954  245.954   747.405
# 11931  7.148  21.0  39003.867  2678.052  9120.889  332.389  332.389   796.457
# 11932  8.206  24.0  50992.579  3087.434  9300.274  438.024  438.024   892.945
# 11933  9.300  27.0  72775.130  3560.400  9742.950  644.880  644.880  1038.411
#
#             T2    P48  ...     TIC     mf   kMc    kMt  status_c_0  \
# 0      550.563  1.096  ...   7.137  0.082  0.95  0.975       Emerg
# 1      581.658  1.331  ...  10.655  0.287  0.95  0.975       Emerg
# 2      587.587  1.389  ...  13.086  0.259  0.95  0.975       Emerg
# 3      613.851  1.658  ...  18.109  0.358  0.95  0.975       Emerg
# 4      645.642  2.078  ...  26.373  0.522  0.95  0.975       Emerg
# ...        ...    ...  ...     ...    ...   ...    ...         ...
# 11929  628.950  2.087  ...  23.803  0.471  1.00  1.000      Normal
# 11930  658.853  2.512  ...  32.671  0.647  1.00  1.000      Normal
# 11931  680.393  2.982  ...  42.104  0.834  1.00  1.000      Normal
# 11932  722.029  3.594  ...  58.064  1.149  1.00  1.000      Normal
# 11933  767.595  4.531  ...  86.067  1.704  1.00  1.000      Normal
#
#        status_t_0 status_c_1 status_t_1 status_c_2 status_t_2
# 0           Emerg      Emerg      Emerg      Emerg      Emerg
# 1           Emerg      Emerg      Emerg      Emerg      Emerg
# 2           Emerg      Emerg      Emerg      Emerg      Emerg
# 3           Emerg      Emerg      Emerg      Emerg      Emerg
# 4           Emerg      Emerg      Emerg      Emerg      Emerg
# ...           ...        ...        ...        ...        ...
# 11929      Normal     Normal     Normal     Normal     Normal
# 11930      Normal     Normal     Normal     Normal     Normal
# 11931      Normal     Normal     Normal     Normal     Normal
# 11932      Normal     Normal     Normal     Normal     Normal
# 11933      Normal     Normal     Normal     Normal     Normal
#
# [11934 rows x 22 columns]

# %%
df.groupby('status_c_0').count()['kMc']
# Out:
# status_c_0
# Emerg     3978
# Alert     3978
# Normal    3978
# Name: kMc, dtype: int64

# %%
df.groupby('status_t_0').count()['kMt']
# Out:
# status_t_0
# Emerg     4131
# Alert     3672
# Normal    4131
# Name: kMt, dtype: int64

# %%
df.groupby('status_c_1').count()['kMc']
# Out:
# status_c_1
# Emerg     1404
# Alert     1170
# Normal    9360
# Name: kMc, dtype: int64

# %%
df.groupby('status_t_1').count()['kMt']
# Out:
# status_t_1
# Emerg     1377
# Alert     1377
# Normal    9180
# Name: kMt, dtype: int64

# %%
df.groupby('status_c_2').count()['kMc']
# Out:
# status_c_2
# Emerg       702
# Alert       702
# Normal    10530
# Name: kMc, dtype: int64

# %%
df.groupby('status_t_2').count()['kMt']
# Out:
# status_t_2
# Emerg       918
# Alert       459
# Normal    10557
# Name: kMt, dtype: int64

# %% [markdown]
# ### Constatações:
# - Cenário 0: Classes balanceadas, não se faz necessária nenhuma técnica de balanceamento do dataset (consequência da escolha arbitrária dos limiares críticos.
# - Cenário 1: Classes desbalanceadas, pode acarretar viés no modelo devido à maior quantidade de exemplos da classe normal. Não faria sentido, contudo, utilizar alguma técnica de oversampling sobre dados simulados, quando se poderia gerar mais dados simulados para estas condições. Pode caber uma técnica de undersampling.
# - Cenário 2: Classes desbalanceadas do que no cenário 1, pode acarretar viés no modelo devido à maior quantidade de exemplos da classe normal. Não faria sentido, contudo, utilizar alguma técnica de oversampling sobre dados simulados, quando se poderia gerar mais dados simulados para estas condições. Pode caber uma técnica de undersampling.

# %% [markdown]
# ### Exclusão das variáveis kMc e kMt do dataset que será fornecido aos modelos de classificação, uma vez que as mesmas foram discretizadas nas variáveis status_c e status_t.

# %%
df2 = df.drop(columns=['kMc', 'kMt'])
df2
# Out:
#           lp     v        GTT       GTn       GGn       Ts       Tp       T48  \
# 0      1.138   3.0    289.964  1349.489  6677.380    7.584    7.584   464.006
# 1      2.088   6.0   6960.180  1376.166  6828.469   28.204   28.204   635.401
# 2      3.144   9.0   8379.229  1386.757  7111.811   60.358   60.358   606.002
# 3      4.161  12.0  14724.395  1547.465  7792.630  113.774  113.774   661.471
# 4      5.140  15.0  21636.432  1924.313  8494.777  175.306  175.306   731.494
# ...      ...   ...        ...       ...       ...      ...      ...       ...
# 11929  5.140  15.0  21624.934  1924.342  8470.013  175.239  175.239   681.658
# 11930  6.175  18.0  29763.213  2306.745  8800.352  245.954  245.954   747.405
# 11931  7.148  21.0  39003.867  2678.052  9120.889  332.389  332.389   796.457
# 11932  8.206  24.0  50992.579  3087.434  9300.274  438.024  438.024   892.945
# 11933  9.300  27.0  72775.130  3560.400  9742.950  644.880  644.880  1038.411
#
#             T2    P48      P2   Pexh     TIC     mf status_c_0 status_t_0  \
# 0      550.563  1.096   5.947  1.019   7.137  0.082      Emerg      Emerg
# 1      581.658  1.331   7.282  1.019  10.655  0.287      Emerg      Emerg
# 2      587.587  1.389   7.574  1.020  13.086  0.259      Emerg      Emerg
# 3      613.851  1.658   9.007  1.022  18.109  0.358      Emerg      Emerg
# 4      645.642  2.078  11.197  1.026  26.373  0.522      Emerg      Emerg
# ...        ...    ...     ...    ...     ...    ...        ...        ...
# 11929  628.950  2.087  10.990  1.027  23.803  0.471     Normal     Normal
# 11930  658.853  2.512  13.109  1.031  32.671  0.647     Normal     Normal
# 11931  680.393  2.982  15.420  1.036  42.104  0.834     Normal     Normal
# 11932  722.029  3.594  18.293  1.043  58.064  1.149     Normal     Normal
# 11933  767.595  4.531  22.464  1.052  86.067  1.704     Normal     Normal
#
#       status_c_1 status_t_1 status_c_2 status_t_2
# 0          Emerg      Emerg      Emerg      Emerg
# 1          Emerg      Emerg      Emerg      Emerg
# 2          Emerg      Emerg      Emerg      Emerg
# 3          Emerg      Emerg      Emerg      Emerg
# 4          Emerg      Emerg      Emerg      Emerg
# ...          ...        ...        ...        ...
# 11929     Normal     Normal     Normal     Normal
# 11930     Normal     Normal     Normal     Normal
# 11931     Normal     Normal     Normal     Normal
# 11932     Normal     Normal     Normal     Normal
# 11933     Normal     Normal     Normal     Normal
#
# [11934 rows x 20 columns]

# %% [markdown]
# ## 4 - Modelagem

# %% [markdown]
# ### Divisão dos datasets de treino e teste para as duas variáveis target  para cada cenário k: status_c_k e status_t_k

# %%
from sklearn.model_selection import train_test_split

# %%
from math import floor

# %%
df2.columns
# Out:
# Index(['lp', 'v', 'GTT', 'GTn', 'GGn', 'Ts', 'Tp', 'T48', 'T2', 'P48', 'P2',
#        'Pexh', 'TIC', 'mf', 'status_c_0', 'status_t_0', 'status_c_1',
#        'status_t_1', 'status_c_2', 'status_t_2'],
#       dtype='object')

# %%
df2
# Out:
#           lp     v        GTT       GTn       GGn       Ts       Tp       T48  \
# 0      1.138   3.0    289.964  1349.489  6677.380    7.584    7.584   464.006
# 1      2.088   6.0   6960.180  1376.166  6828.469   28.204   28.204   635.401
# 2      3.144   9.0   8379.229  1386.757  7111.811   60.358   60.358   606.002
# 3      4.161  12.0  14724.395  1547.465  7792.630  113.774  113.774   661.471
# 4      5.140  15.0  21636.432  1924.313  8494.777  175.306  175.306   731.494
# ...      ...   ...        ...       ...       ...      ...      ...       ...
# 11929  5.140  15.0  21624.934  1924.342  8470.013  175.239  175.239   681.658
# 11930  6.175  18.0  29763.213  2306.745  8800.352  245.954  245.954   747.405
# 11931  7.148  21.0  39003.867  2678.052  9120.889  332.389  332.389   796.457
# 11932  8.206  24.0  50992.579  3087.434  9300.274  438.024  438.024   892.945
# 11933  9.300  27.0  72775.130  3560.400  9742.950  644.880  644.880  1038.411
#
#             T2    P48      P2   Pexh     TIC     mf status_c_0 status_t_0  \
# 0      550.563  1.096   5.947  1.019   7.137  0.082      Emerg      Emerg
# 1      581.658  1.331   7.282  1.019  10.655  0.287      Emerg      Emerg
# 2      587.587  1.389   7.574  1.020  13.086  0.259      Emerg      Emerg
# 3      613.851  1.658   9.007  1.022  18.109  0.358      Emerg      Emerg
# 4      645.642  2.078  11.197  1.026  26.373  0.522      Emerg      Emerg
# ...        ...    ...     ...    ...     ...    ...        ...        ...
# 11929  628.950  2.087  10.990  1.027  23.803  0.471     Normal     Normal
# 11930  658.853  2.512  13.109  1.031  32.671  0.647     Normal     Normal
# 11931  680.393  2.982  15.420  1.036  42.104  0.834     Normal     Normal
# 11932  722.029  3.594  18.293  1.043  58.064  1.149     Normal     Normal
# 11933  767.595  4.531  22.464  1.052  86.067  1.704     Normal     Normal
#
#       status_c_1 status_t_1 status_c_2 status_t_2
# 0          Emerg      Emerg      Emerg      Emerg
# 1          Emerg      Emerg      Emerg      Emerg
# 2          Emerg      Emerg      Emerg      Emerg
# 3          Emerg      Emerg      Emerg      Emerg
# 4          Emerg      Emerg      Emerg      Emerg
# ...          ...        ...        ...        ...
# 11929     Normal     Normal     Normal     Normal
# 11930     Normal     Normal     Normal     Normal
# 11931     Normal     Normal     Normal     Normal
# 11932     Normal     Normal     Normal     Normal
# 11933     Normal     Normal     Normal     Normal
#
# [11934 rows x 20 columns]

# %%
X = df2.drop(columns=['status_c_0', 'status_t_0', 'status_c_1', 'status_t_1', 'status_c_2', 'status_t_2'])

# %%
y = [df[col] for col in ['status_c_0', 'status_t_0', 'status_c_1', 'status_t_1', 'status_c_2', 'status_t_2']]

# %%
# Cria uma lista de dados de treino e teste de acordo com a lista de vetores de saída y
# Índice 0: X_train, X_test, y_train, y_test para a saída status_c_0, etc.
conj_treino_teste = []
for saida in y:
    X_train, X_test, y_train, y_test = train_test_split(X, saida, test_size=0.3)
    conj_treino_teste.append([X_train, X_test, y_train, y_test])

# %% [markdown]
# ## Teste de modelos de classificação

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.ensemble import AdaBoostClassifier
from sklearn.metrics import classification_report

# %%
import warnings
warnings.simplefilter("ignore")

# %%
# Para cada saída que se quer prever, cria-se uma instância de um dos modelos de classificação
# Ou seja, 6 modelos para 6 saídas, 36 treinamentos distintos
modelos = [
    {'DecisionTree_comp_0': DecisionTreeClassifier(),
    'RandomForest_comp_0': RandomForestClassifier(),
    'KNN_comp_0': KNeighborsClassifier(),
    'GaussianNB_comp_0': GaussianNB(),
    'SVC_comp_0': SVC(),
    'AdaBoost_comp_0': AdaBoostClassifier()},
    
    {'DecisionTree_turb_0': DecisionTreeClassifier(),
    'RandomForest_turb_0': RandomForestClassifier(),
    'KNN_turb_0': KNeighborsClassifier(),
    'GaussianNB_turb_0': GaussianNB(),
    'SVC_turb_0': SVC(),
    'AdaBoost_turb_0': AdaBoostClassifier()},
    
    {'DecisionTree_comp_1': DecisionTreeClassifier(),
    'RandomForest_comp_1': RandomForestClassifier(),
    'KNN_comp_1': KNeighborsClassifier(),
    'GaussianNB_comp_1': GaussianNB(),
    'SVC_comp_1': SVC(),
    'AdaBoost_comp_1': AdaBoostClassifier()},    
    
    {'DecisionTree_turb_1': DecisionTreeClassifier(),
    'RandomForest_turb_1': RandomForestClassifier(),
    'KNN_turb_1': KNeighborsClassifier(),
    'GaussianNB_turb_1': GaussianNB(),
    'SVC_turb_1': SVC(),
    'AdaBoost_turb_1': AdaBoostClassifier()},
    
    {'DecisionTree_comp_2': DecisionTreeClassifier(),
    'RandomForest_comp_2': RandomForestClassifier(),
    'KNN_comp_2': KNeighborsClassifier(),
    'GaussianNB_comp_2': GaussianNB(),
    'SVC_comp_2': SVC(),
    'AdaBoost_comp_2': AdaBoostClassifier()},
    
    {'DecisionTree_turb_2': DecisionTreeClassifier(),
    'RandomForest_turb_2': RandomForestClassifier(),
    'KNN_turb_2': KNeighborsClassifier(),
    'GaussianNB_turb_2': GaussianNB(),
    'SVC_turb_2': SVC(),
    'AdaBoost_turb_2': AdaBoostClassifier()}]

# %%
result = {'Modelo': [], 'Estagio': [], 'Cenario': [], 'Acuracia': [], 'Recall_Emerg': [], 'F1-score_Emerg': []}

# %%
# %%time
i = 0
for dic_mod, data in zip(modelos, conj_treino_teste):
    for mod in dic_mod:
        print('#################################################################')
        
        result['Modelo'].append(mod)
        print(f'Modelo {mod}')
               
        # São 12 modelos para cada cenário
        result['Cenario'].append(floor(i/12))
        print(f'Cenário {floor(i/12)}')

        # Primeira metade dos modelos do cenário são compressor, outra metade turbina
        if(floor(i/6)%2) == 0:
            result['Estagio'].append('Compressor')
            print('Estágio: Compressor')
        else:
            result['Estagio'].append('Turbina')
            print('Estágio: Turbina')
            
        i+=1
        
        # Treinando o modelo
        dic_mod[mod].fit(data[0], data[2])
        
        # Fazendo previsões
        Y_pred = dic_mod[mod].predict(data[1])
        
        # Resultado
        report = classification_report(data[3], Y_pred, output_dict=True)
        print(report)
        
        # Gravando resultados do report em um dataframe para comparação posterior
        result['Acuracia'].append(report['accuracy'])
        result['Recall_Emerg'].append(report['Emerg']['recall'])
        result['F1-score_Emerg'].append(report['Emerg']['f1-score'])
    
resultados = pd.DataFrame.from_dict(result)
# Out:
# #################################################################
# Modelo DecisionTree_comp_0
# Cenário 0
# Estágio: Compressor
# {'Alert': {'precision': 0.9313482216708023, 'recall': 0.9267489711934156, 'f1-score': 0.9290429042904291, 'support': 1215}, 'Emerg': {'precision': 0.9616985845129059, 'recall': 0.9738617200674536, 'f1-score': 0.967741935483871, 'support': 1186}, 'Normal': {'precision': 0.9615713065755764, 'recall': 0.9542372881355933, 'f1-score': 0.9578902594640578, 'support': 1180}, 'accuracy': 0.9514102206087685, 'macro avg': {'precision': 0.9515393709197616, 'recall': 0.9516159931321542, 'f1-score': 0.9515583664127859, 'support': 3581}, 'weighted avg': {'precision': 0.9513590484003103, 'recall': 0.9514102206087685, 'f1-score': 0.9513654203754065, 'support': 3581}}
# #################################################################
# Modelo RandomForest_comp_0
# Cenário 0
# Estágio: Compressor
# {'Alert': {'precision': 0.9399837793998378, 'recall': 0.9539094650205762, 'f1-score': 0.9468954248366013, 'support': 1215}, 'Emerg': {'precision': 0.970513900589722, 'recall': 0.9713322091062394, 'f1-score': 0.9709228824273072, 'support': 1186}, 'Normal': {'precision': 0.9819121447028424, 'recall': 0.9661016949152542, 'f1-score': 0.9739427595044853, 'support': 1180}, 'accuracy': 0.9636972912594247, 'macro avg': {'precision': 0.9641366082308007, 'recall': 0.9637811230140233, 'f1-score': 0.9639203555894645, 'support': 3581}, 'weighted avg': {'precision': 0.9639112283774274, 'recall': 0.9636972912594247, 'f1-score': 0.9637656900169085, 'support': 3581}}
# #################################################################
# Modelo KNN_comp_0
# Cenário 0
# Estágio: Compressor
# {'Alert': {'precision': 0.8919135308246597, 'recall': 0.9168724279835391, 'f1-score': 0.9042207792207791, 'support': 1215}, 'Emerg': {'precision': 0.9616055846422339, 'recall': 0.9291736930860034, 'f1-score': 0.9451114922813035, 'support': 1186}, 'Normal': {'precision': 0.9376053962900506, 'recall': 0.9423728813559322, 'f1-score': 0.9399830938292477, 'support': 1180}, 'accuracy': 0.9293493437587266, 'macro avg': {'precision': 0.9303748372523147, 'recall': 0.9294730008084916, 'f1-score': 0.9297717884437767, 'support': 3581}, 'weighted avg': {'precision': 0.9300512513152499, 'recall': 0.9293493437587266, 'f1-score': 0.9295477596529977, 'support': 3581}}
# #################################################################
# Modelo GaussianNB_comp_0
# Cenário 0
# Estágio: Compressor
# {'Alert': {'precision': 0.3291245791245791, 'recall': 0.6436213991769547, 'f1-score': 0.43553327763854083, 'support': 1215}, 'Emerg': {'precision': 0.31867219917012446, 'recall': 0.32377740303541314, 'f1-score': 0.3212045169385194, 'support': 1186}, 'Normal': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 1180}, 'accuracy': 0.3256073722423904, 'macro avg': {'precision': 0.21593225943156788, 'recall': 0.3224662674041226, 'f1-score': 0.25224593152568675, 'support': 3581}, 'weighted avg': {'precision': 0.2172107209863533, 'recall': 0.3256073722423904, 'f1-score': 0.25415288729961216, 'support': 3581}}
# #################################################################
# Modelo SVC_comp_0
# Cenário 0
# Estágio: Compressor
# {'Alert': {'precision': 0.3, 'recall': 0.007407407407407408, 'f1-score': 0.014457831325301205, 'support': 1215}, 'Emerg': {'precision': 0.3242034656232532, 'recall': 0.48903878583473864, 'f1-score': 0.3899159663865546, 'support': 1186}, 'Normal': {'precision': 0.34619750283768447, 'recall': 0.5169491525423728, 'f1-score': 0.41468388851121685, 'support': 1180}, 'accuracy': 0.33482267523038256, 'macro avg': {'precision': 0.3234669894869792, 'recall': 0.3377984485948396, 'f1-score': 0.27301922874102424, 'support': 3581}, 'weighted avg': {'precision': 0.3232388616525122, 'recall': 0.33482267523038256, 'f1-score': 0.27068796136217, 'support': 3581}}
# #################################################################
# Modelo AdaBoost_comp_0
# Cenário 0
# Estágio: Compressor
# {'Alert': {'precision': 0.5344732487589631, 'recall': 0.7975308641975308, 'f1-score': 0.6400264200792602, 'support': 1215}, 'Emerg': {'precision': 0.8342541436464088, 'recall': 0.636593591905565, 'f1-score': 0.7221425155428026, 'support': 1186}, 'Normal': {'precision': 0.8597914252607184, 'recall': 0.6288135593220339, 'f1-score': 0.7263827704356338, 'support': 1180}, 'accuracy': 0.688634459648143, 'macro avg': {'precision': 0.7428396058886969, 'recall': 0.6876460051417098, 'f1-score': 0.6961839020192322, 'support': 3581}, 'weighted avg': {'precision': 0.7409562394343561, 'recall': 0.688634459648143, 'f1-score': 0.6956785235811541, 'support': 3581}}
# #################################################################
# Modelo DecisionTree_turb_0
# Cenário 0
# Estágio: Turbina
# {'Alert': {'precision': 0.9007155635062611, 'recall': 0.9121376811594203, 'f1-score': 0.9063906390639063, 'support': 1104}, 'Emerg': {'precision': 0.9608163265306122, 'recall': 0.953808752025932, 'f1-score': 0.9572997153314355, 'support': 1234}, 'Normal': {'precision': 0.9563812600969306, 'recall': 0.9525341914722446, 'f1-score': 0.954453849254333, 'support': 1243}, 'accuracy': 0.940519407986596, 'macro avg': {'precision': 0.9393043833779346, 'recall': 0.9394935415525323, 'f1-score': 0.9393814012165582, 'support': 3581}, 'weighted avg': {'precision': 0.9407481807735751, 'recall': 0.940519407986596, 'f1-score': 0.9406169362939625, 'support': 3581}}
# #################################################################
# Modelo RandomForest_turb_0
# Cenário 0
# Estágio: Turbina
# {'Alert': {'precision': 0.9563636363636364, 'recall': 0.9528985507246377, 'f1-score': 0.9546279491833031, 'support': 1104}, 'Emerg': {'precision': 0.9797898140662894, 'recall': 0.9821717990275527, 'f1-score': 0.98097936058276, 'support': 1234}, 'Normal': {'precision': 0.977491961414791, 'recall': 0.9782783588093322, 'f1-score': 0.9778850020104544, 'support': 1243}, 'accuracy': 0.9717955878246299, 'macro avg': {'precision': 0.9712151372815723, 'recall': 0.9711162361871741, 'f1-score': 0.9711641039255058, 'support': 3581}, 'weighted avg': {'precision': 0.9717700623127175, 'recall': 0.9717955878246299, 'f1-score': 0.9717813025290385, 'support': 3581}}
# #################################################################
# Modelo KNN_turb_0
# Cenário 0
# Estágio: Turbina
# {'Alert': {'precision': 0.8226768968456948, 'recall': 0.8740942028985508, 'f1-score': 0.8476064997804129, 'support': 1104}, 'Emerg': {'precision': 0.9004777070063694, 'recall': 0.9165316045380876, 'f1-score': 0.9084337349397591, 'support': 1234}, 'Normal': {'precision': 0.9383680555555556, 'recall': 0.8696701528559936, 'f1-score': 0.9027139874739041, 'support': 1243}, 'accuracy': 0.88718235129852, 'macro avg': {'precision': 0.88717421980254, 'recall': 0.8867653200975439, 'f1-score': 0.8862514073980253, 'support': 3581}, 'weighted avg': {'precision': 0.8896443109799115, 'recall': 0.88718235129852, 'f1-score': 0.8876956970408549, 'support': 3581}}
# #################################################################
# Modelo GaussianNB_turb_0
# Cenário 0
# Estágio: Turbina
# {'Alert': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 1104}, 'Emerg': {'precision': 0.3943502824858757, 'recall': 0.28282009724473256, 'f1-score': 0.3294006606890042, 'support': 1234}, 'Normal': {'precision': 0.35756676557863504, 'recall': 0.7755430410297667, 'f1-score': 0.48946433104848946, 'support': 1243}, 'accuracy': 0.3666573582798101, 'macro avg': {'precision': 0.25063901602150357, 'recall': 0.35278771275816645, 'f1-score': 0.2729549972458312, 'support': 3581}, 'weighted avg': {'precision': 0.2600066289309729, 'recall': 0.3666573582798101, 'f1-score': 0.28340814822214566, 'support': 3581}}
# #################################################################
# Modelo SVC_turb_0
# Cenário 0
# Estágio: Turbina
# {'Alert': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 1104}, 'Emerg': {'precision': 0.33631165117941386, 'recall': 0.7625607779578606, 'f1-score': 0.466765873015873, 'support': 1234}, 'Normal': {'precision': 0.30779054916985954, 'recall': 0.19388576025744167, 'f1-score': 0.23790720631786771, 'support': 1243}, 'accuracy': 0.33007539793353813, 'macro avg': {'precision': 0.2147007334497578, 'recall': 0.31881551273843406, 'f1-score': 0.23489102644458026, 'support': 3581}, 'weighted avg': {'precision': 0.2227289109671969, 'recall': 0.33007539793353813, 'f1-score': 0.2434257874210268, 'support': 3581}}
# #################################################################
# Modelo AdaBoost_turb_0
# Cenário 0
# Estágio: Turbina
# {'Alert': {'precision': 0.46722560975609756, 'recall': 0.5552536231884058, 'f1-score': 0.5074503311258278, 'support': 1104}, 'Emerg': {'precision': 0.6881569726699369, 'recall': 0.7957860615883307, 'f1-score': 0.7380683953400977, 'support': 1234}, 'Normal': {'precision': 0.7814726840855107, 'recall': 0.5293644408688657, 'f1-score': 0.6311750599520384, 'support': 1243}, 'accuracy': 0.6291538676347389, 'macro avg': {'precision': 0.6456184221705151, 'recall': 0.6268013752152006, 'f1-score': 0.6255645954726546, 'support': 3581}, 'weighted avg': {'precision': 0.6524360021680322, 'recall': 0.6291538676347389, 'f1-score': 0.6298665637902761, 'support': 3581}}
# #################################################################
# Modelo DecisionTree_comp_1
# Cenário 1
# Estágio: Compressor
# {'Alert': {'precision': 0.749271137026239, 'recall': 0.7907692307692308, 'f1-score': 0.7694610778443113, 'support': 325}, 'Emerg': {'precision': 0.9221411192214112, 'recall': 0.8793503480278422, 'f1-score': 0.9002375296912113, 'support': 431}, 'Normal': {'precision': 0.9869119207640609, 'recall': 0.9876106194690265, 'f1-score': 0.9872611464968152, 'support': 2825}, 'accuracy': 0.9567160011170064, 'macro avg': {'precision': 0.8861080590039038, 'recall': 0.8859100660886998, 'f1-score': 0.8856532513441127, 'support': 3581}, 'weighted avg': {'precision': 0.9575487623782262, 'recall': 0.9567160011170064, 'f1-score': 0.95702037543977, 'support': 3581}}
# #################################################################
# Modelo RandomForest_comp_1
# Cenário 1
# Estágio: Compressor
# {'Alert': {'precision': 0.8373493975903614, 'recall': 0.8553846153846154, 'f1-score': 0.8462709284627093, 'support': 325}, 'Emerg': {'precision': 0.9418886198547215, 'recall': 0.9025522041763341, 'f1-score': 0.9218009478672986, 'support': 431}, 'Normal': {'precision': 0.9911847672778561, 'recall': 0.9950442477876106, 'f1-score': 0.9931107578166402, 'support': 2825}, 'accuracy': 0.9712370846132365, 'macro avg': {'precision': 0.923474261574313, 'recall': 0.9176603557828534, 'f1-score': 0.9203942113822161, 'support': 3581}, 'weighted avg': {'precision': 0.9712900075214175, 'recall': 0.9712370846132365, 'f1-score': 0.9712013826063096, 'support': 3581}}
# #################################################################
# Modelo KNN_comp_1
# Cenário 1
# Estágio: Compressor
# {'Alert': {'precision': 0.8498402555910544, 'recall': 0.8184615384615385, 'f1-score': 0.8338557993730408, 'support': 325}, 'Emerg': {'precision': 0.9181585677749361, 'recall': 0.8329466357308585, 'f1-score': 0.8734793187347932, 'support': 431}, 'Normal': {'precision': 0.9753215154675009, 'recall': 0.9932743362831858, 'f1-score': 0.9842160645387583, 'support': 2825}, 'accuracy': 0.9581122591454901, 'macro avg': {'precision': 0.9144401129444971, 'recall': 0.8815608368251943, 'f1-score': 0.8971837275488642, 'support': 3581}, 'weighted avg': {'precision': 0.9570532552286457, 'recall': 0.9581122591454901, 'f1-score': 0.9572418607910992, 'support': 3581}}
# #################################################################
# Modelo GaussianNB_comp_1
# Cenário 1
# Estágio: Compressor
# {'Alert': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 325}, 'Emerg': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 431}, 'Normal': {'precision': 0.7888857860932701, 'recall': 1.0, 'f1-score': 0.8819856384639401, 'support': 2825}, 'accuracy': 0.7888857860932701, 'macro avg': {'precision': 0.2629619286977567, 'recall': 0.3333333333333333, 'f1-score': 0.29399521282131336, 'support': 3581}, 'weighted avg': {'precision': 0.6223407834999967, 'recall': 0.7888857860932701, 'f1-score': 0.6957859337226, 'support': 3581}}
# #################################################################
# Modelo SVC_comp_1
# Cenário 1
# Estágio: Compressor
# {'Alert': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 325}, 'Emerg': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 431}, 'Normal': {'precision': 0.7888857860932701, 'recall': 1.0, 'f1-score': 0.8819856384639401, 'support': 2825}, 'accuracy': 0.7888857860932701, 'macro avg': {'precision': 0.2629619286977567, 'recall': 0.3333333333333333, 'f1-score': 0.29399521282131336, 'support': 3581}, 'weighted avg': {'precision': 0.6223407834999967, 'recall': 0.7888857860932701, 'f1-score': 0.6957859337226, 'support': 3581}}
# #################################################################
# Modelo AdaBoost_comp_1
# Cenário 1
# Estágio: Compressor
# {'Alert': {'precision': 0.40476190476190477, 'recall': 0.36615384615384616, 'f1-score': 0.38449111470113084, 'support': 325}, 'Emerg': {'precision': 0.743801652892562, 'recall': 0.4176334106728538, 'f1-score': 0.5349182763744427, 'support': 431}, 'Normal': {'precision': 0.9205254515599344, 'recall': 0.992212389380531, 'f1-score': 0.9550255536626917, 'support': 2825}, 'accuracy': 0.866238480871265, 'macro avg': {'precision': 0.6896963364048004, 'recall': 0.5919998820690769, 'f1-score': 0.6248116482460885, 'support': 3581}, 'weighted avg': {'precision': 0.8524463926559978, 'recall': 0.866238480871265, 'f1-score': 0.8526826524692421, 'support': 3581}}
# #################################################################
# Modelo DecisionTree_turb_1
# Cenário 1
# Estágio: Turbina
# {'Alert': {'precision': 0.7899761336515513, 'recall': 0.8112745098039216, 'f1-score': 0.8004836759371221, 'support': 408}, 'Emerg': {'precision': 0.9074550128534704, 'recall': 0.8802992518703242, 'f1-score': 0.8936708860759495, 'support': 401}, 'Normal': {'precision': 0.9812477461233321, 'recall': 0.9816017316017316, 'f1-score': 0.9814247069431921, 'support': 2772}, 'accuracy': 0.9508517173973751, 'macro avg': {'precision': 0.8928929642094513, 'recall': 0.8910584977586592, 'f1-score': 0.8918597563187545, 'support': 3581}, 'weighted avg': {'precision': 0.9511919784802991, 'recall': 0.9508517173973751, 'f1-score': 0.9509825894290225, 'support': 3581}}
# #################################################################
# Modelo RandomForest_turb_1
# Cenário 1
# Estágio: Turbina
# {'Alert': {'precision': 0.8627450980392157, 'recall': 0.8627450980392157, 'f1-score': 0.8627450980392157, 'support': 408}, 'Emerg': {'precision': 0.9566395663956639, 'recall': 0.8802992518703242, 'f1-score': 0.9168831168831169, 'support': 401}, 'Normal': {'precision': 0.9818116975748931, 'recall': 0.9931457431457431, 'f1-score': 0.9874461979913917, 'support': 2772}, 'accuracy': 0.9656520524993019, 'macro avg': {'precision': 0.9337321206699243, 'recall': 0.912063364351761, 'f1-score': 0.9223581376379081, 'support': 3581}, 'weighted avg': {'precision': 0.9654271130416825, 'recall': 0.9656520524993019, 'f1-score': 0.9653367748400635, 'support': 3581}}
# #################################################################
# Modelo KNN_turb_1
# Cenário 1
# Estágio: Turbina
# {'Alert': {'precision': 0.7785888077858881, 'recall': 0.7843137254901961, 'f1-score': 0.7814407814407814, 'support': 408}, 'Emerg': {'precision': 0.9054441260744985, 'recall': 0.7880299251870324, 'f1-score': 0.8426666666666667, 'support': 401}, 'Normal': {'precision': 0.9599432825239277, 'recall': 0.976911976911977, 'f1-score': 0.968353298766315, 'support': 2772}, 'accuracy': 0.9338173694498744, 'macro avg': {'precision': 0.8813254054614381, 'recall': 0.8497518758630686, 'f1-score': 0.8641535822912543, 'support': 3581}, 'weighted avg': {'precision': 0.9331779132334107, 'recall': 0.9338173694498744, 'f1-score': 0.9329831098412168, 'support': 3581}}
# #################################################################
# Modelo GaussianNB_turb_1
# Cenário 1
# Estágio: Turbina
# {'Alert': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 408}, 'Emerg': {'precision': 0.5, 'recall': 0.00997506234413965, 'f1-score': 0.019559902200488994, 'support': 401}, 'Normal': {'precision': 0.7758186397984886, 'recall': 1.0, 'f1-score': 0.873758865248227, 'support': 2772}, 'accuracy': 0.7752024574141302, 'macro avg': {'precision': 0.42527287993282953, 'recall': 0.33665835411471323, 'f1-score': 0.2977729224829053, 'support': 3581}, 'weighted avg': {'precision': 0.6565398686180984, 'recall': 0.7752024574141302, 'f1-score': 0.6785543410361579, 'support': 3581}}
# #################################################################
# Modelo SVC_turb_1
# Cenário 1
# Estágio: Turbina
# {'Alert': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 408}, 'Emerg': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 401}, 'Normal': {'precision': 0.7740854509913432, 'recall': 1.0, 'f1-score': 0.8726585864945694, 'support': 2772}, 'accuracy': 0.7740854509913432, 'macro avg': {'precision': 0.25802848366378106, 'recall': 0.3333333333333333, 'f1-score': 0.2908861954981898, 'support': 3581}, 'weighted avg': {'precision': 0.5992082854364712, 'recall': 0.7740854509913432, 'f1-score': 0.6755123154881167, 'support': 3581}}
# #################################################################
# Modelo AdaBoost_turb_1
# Cenário 1
# Estágio: Turbina
# {'Alert': {'precision': 0.4393939393939394, 'recall': 0.14215686274509803, 'f1-score': 0.2148148148148148, 'support': 408}, 'Emerg': {'precision': 0.6767676767676768, 'recall': 0.3341645885286783, 'f1-score': 0.4474123539232054, 'support': 401}, 'Normal': {'precision': 0.8474315595201476, 'recall': 0.9938672438672439, 'f1-score': 0.914826498422713, 'support': 2772}, 'accuracy': 0.8229544819882715, 'macro avg': {'precision': 0.6545310585605879, 'recall': 0.49006289838034006, 'f1-score': 0.5256845557202444, 'support': 3581}, 'weighted avg': {'precision': 0.7818310105128218, 'recall': 0.8229544819882715, 'f1-score': 0.782729922366772, 'support': 3581}}
# #################################################################
# Modelo DecisionTree_comp_2
# Cenário 2
# Estágio: Compressor
# {'Alert': {'precision': 0.6577777777777778, 'recall': 0.6727272727272727, 'f1-score': 0.6651685393258427, 'support': 220}, 'Emerg': {'precision': 0.8541666666666666, 'recall': 0.7592592592592593, 'f1-score': 0.8039215686274509, 'support': 216}, 'Normal': {'precision': 0.9848293299620733, 'recall': 0.9907790143084261, 'f1-score': 0.9877952131875098, 'support': 3145}, 'accuracy': 0.9572745043283999, 'macro avg': {'precision': 0.8322579248021725, 'recall': 0.8075885154316526, 'f1-score': 0.8189617737136011, 'support': 3581}, 'weighted avg': {'precision': 0.9568554464791488, 'recall': 0.9572745043283999, 'f1-score': 0.9568835752443265, 'support': 3581}}
# #################################################################
# Modelo RandomForest_comp_2
# Cenário 2
# Estágio: Compressor
# {'Alert': {'precision': 0.7412935323383084, 'recall': 0.6772727272727272, 'f1-score': 0.7078384798099763, 'support': 220}, 'Emerg': {'precision': 0.8952879581151832, 'recall': 0.7916666666666666, 'f1-score': 0.8402948402948403, 'support': 216}, 'Normal': {'precision': 0.9814989024772656, 'recall': 0.9952305246422893, 'f1-score': 0.9883170192611302, 'support': 3145}, 'accuracy': 0.963418039653728, 'macro avg': {'precision': 0.8726934643102524, 'recall': 0.821389972860561, 'f1-score': 0.8454834464553156, 'support': 3581}, 'weighted avg': {'precision': 0.9615416990668271, 'recall': 0.963418039653728, 'f1-score': 0.9621572679804902, 'support': 3581}}
# #################################################################
# Modelo KNN_comp_2
# Cenário 2
# Estágio: Compressor
# {'Alert': {'precision': 0.7989690721649485, 'recall': 0.7045454545454546, 'f1-score': 0.748792270531401, 'support': 220}, 'Emerg': {'precision': 0.8429319371727748, 'recall': 0.7453703703703703, 'f1-score': 0.791154791154791, 'support': 216}, 'Normal': {'precision': 0.977784730913642, 'recall': 0.9936406995230525, 'f1-score': 0.9856489512695158, 'support': 3145}, 'accuracy': 0.9609047752024574, 'macro avg': {'precision': 0.8732285800837886, 'recall': 0.8145188414796257, 'f1-score': 0.8418653376519026, 'support': 3581}, 'weighted avg': {'precision': 0.958665030167275, 'recall': 0.9609047752024574, 'f1-score': 0.9593660112116644, 'support': 3581}}
# #################################################################
# Modelo GaussianNB_comp_2
# Cenário 2
# Estágio: Compressor
# {'Alert': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 220}, 'Emerg': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 216}, 'Normal': {'precision': 0.8782462999162245, 'recall': 1.0, 'f1-score': 0.935176925364258, 'support': 3145}, 'accuracy': 0.8782462999162245, 'macro avg': {'precision': 0.2927487666387415, 'recall': 0.3333333333333333, 'f1-score': 0.311725641788086, 'support': 3581}, 'weighted avg': {'precision': 0.771316563316539, 'recall': 0.8782462999162245, 'f1-score': 0.8213156744681909, 'support': 3581}}
# #################################################################
# Modelo SVC_comp_2
# Cenário 2
# Estágio: Compressor
# {'Alert': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 220}, 'Emerg': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 216}, 'Normal': {'precision': 0.8782462999162245, 'recall': 1.0, 'f1-score': 0.935176925364258, 'support': 3145}, 'accuracy': 0.8782462999162245, 'macro avg': {'precision': 0.2927487666387415, 'recall': 0.3333333333333333, 'f1-score': 0.311725641788086, 'support': 3581}, 'weighted avg': {'precision': 0.771316563316539, 'recall': 0.8782462999162245, 'f1-score': 0.8213156744681909, 'support': 3581}}
# #################################################################
# Modelo AdaBoost_comp_2
# Cenário 2
# Estágio: Compressor
# {'Alert': {'precision': 0.32075471698113206, 'recall': 0.07727272727272727, 'f1-score': 0.12454212454212453, 'support': 220}, 'Emerg': {'precision': 0.6842105263157895, 'recall': 0.06018518518518518, 'f1-score': 0.1106382978723404, 'support': 216}, 'Normal': {'precision': 0.8917070390424623, 'recall': 0.9949125596184419, 'f1-score': 0.9404869251577999, 'support': 3145}, 'accuracy': 0.8821558223959788, 'macro avg': {'precision': 0.632224094113128, 'recall': 0.37745682402545144, 'f1-score': 0.3918891158574216, 'support': 3581}, 'weighted avg': {'precision': 0.8441145348250777, 'recall': 0.8821558223959788, 'f1-score': 0.8403039707793838, 'support': 3581}}
# #################################################################
# Modelo DecisionTree_turb_2
# Cenário 2
# Estágio: Turbina
# {'Alert': {'precision': 0.46206896551724136, 'recall': 0.46853146853146854, 'f1-score': 0.46527777777777773, 'support': 143}, 'Emerg': {'precision': 0.7865612648221344, 'recall': 0.7262773722627737, 'f1-score': 0.7552182163187856, 'support': 274}, 'Normal': {'precision': 0.979579013509268, 'recall': 0.9854614412136536, 'f1-score': 0.9825114227193951, 'support': 3164}, 'accuracy': 0.9449874336777436, 'macro avg': {'precision': 0.7427364146162145, 'recall': 0.7267567606692986, 'f1-score': 0.7343358056053195, 'support': 3581}, 'weighted avg': {'precision': 0.9441445538602496, 'recall': 0.9449874336777436, 'f1-score': 0.9444654160786751, 'support': 3581}}
# #################################################################
# Modelo RandomForest_turb_2
# Cenário 2
# Estágio: Turbina
# {'Alert': {'precision': 0.7471264367816092, 'recall': 0.45454545454545453, 'f1-score': 0.5652173913043478, 'support': 143}, 'Emerg': {'precision': 0.8783269961977186, 'recall': 0.843065693430657, 'f1-score': 0.8603351955307262, 'support': 274}, 'Normal': {'precision': 0.9764778706282885, 'recall': 0.9971554993678887, 'f1-score': 0.9867083659108679, 'support': 3164}, 'accuracy': 0.9636972912594247, 'macro avg': {'precision': 0.8673104345358721, 'recall': 0.7649222157813335, 'f1-score': 0.8040869842486473, 'support': 3581}, 'weighted avg': {'precision': 0.959809176231737, 'recall': 0.9636972912594247, 'f1-score': 0.9602075398698483, 'support': 3581}}
# #################################################################
# Modelo KNN_turb_2
# Cenário 2
# Estágio: Turbina
# {'Alert': {'precision': 0.6170212765957447, 'recall': 0.40559440559440557, 'f1-score': 0.48945147679324896, 'support': 143}, 'Emerg': {'precision': 0.7962264150943397, 'recall': 0.7700729927007299, 'f1-score': 0.7829313543599259, 'support': 274}, 'Normal': {'precision': 0.9717566728739913, 'recall': 0.9895701643489254, 'f1-score': 0.9805825242718447, 'support': 3164}, 'accuracy': 0.9494554593688914, 'macro avg': {'precision': 0.7950014548546919, 'recall': 0.721745854214687, 'f1-score': 0.75098845180834, 'support': 3581}, 'weighted avg': {'precision': 0.9441603443904911, 'recall': 0.9494554593688914, 'f1-score': 0.9458469307657557, 'support': 3581}}
# #################################################################
# Modelo GaussianNB_turb_2
# Cenário 2
# Estágio: Turbina
# {'Alert': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 143}, 'Emerg': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 274}, 'Normal': {'precision': 0.8835520804244624, 'recall': 1.0, 'f1-score': 0.9381764269829502, 'support': 3164}, 'accuracy': 0.8835520804244624, 'macro avg': {'precision': 0.2945173601414875, 'recall': 0.3333333333333333, 'f1-score': 0.3127254756609834, 'support': 3581}, 'weighted avg': {'precision': 0.7806642788223958, 'recall': 0.8835520804244624, 'f1-score': 0.8289277338659745, 'support': 3581}}
# #################################################################
# Modelo SVC_turb_2
# Cenário 2
# Estágio: Turbina
# {'Alert': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 143}, 'Emerg': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 274}, 'Normal': {'precision': 0.8835520804244624, 'recall': 1.0, 'f1-score': 0.9381764269829502, 'support': 3164}, 'accuracy': 0.8835520804244624, 'macro avg': {'precision': 0.2945173601414875, 'recall': 0.3333333333333333, 'f1-score': 0.3127254756609834, 'support': 3581}, 'weighted avg': {'precision': 0.7806642788223958, 'recall': 0.8835520804244624, 'f1-score': 0.8289277338659745, 'support': 3581}}
# #################################################################
# Modelo AdaBoost_turb_2
# Cenário 2
# Estágio: Turbina
# {'Alert': {'precision': 0.375, 'recall': 0.02097902097902098, 'f1-score': 0.039735099337748346, 'support': 143}, 'Emerg': {'precision': 0.7368421052631579, 'recall': 0.10218978102189781, 'f1-score': 0.1794871794871795, 'support': 274}, 'Normal': {'precision': 0.8939179632248939, 'recall': 0.9987357774968394, 'f1-score': 0.9434243917002536, 'support': 3164}, 'accuracy': 0.8910918737782743, 'macro avg': {'precision': 0.6685866894960174, 'recall': 0.3739681931659194, 'f1-score': 0.3875488901750605, 'support': 3581}, 'weighted avg': {'precision': 0.8611773729365177, 'recall': 0.8910918737782743, 'f1-score': 0.8488847756839955, 'support': 3581}}
# CPU times: user 35.5 s, sys: 421 ms, total: 35.9 s
# Wall time: 35.9 s

# %%
# Dataset resultante com os resultados coletados do treinamento dos modelos
resultados
# Out:
#                  Modelo     Estagio  Cenario  Acuracia  Recall_Emerg  \
# 0   DecisionTree_comp_0  Compressor        0  0.951410      0.973862
# 1   RandomForest_comp_0  Compressor        0  0.963697      0.971332
# 2            KNN_comp_0  Compressor        0  0.929349      0.929174
# 3     GaussianNB_comp_0  Compressor        0  0.325607      0.323777
# 4            SVC_comp_0  Compressor        0  0.334823      0.489039
# 5       AdaBoost_comp_0  Compressor        0  0.688634      0.636594
# 6   DecisionTree_turb_0     Turbina        0  0.940519      0.953809
# 7   RandomForest_turb_0     Turbina        0  0.971796      0.982172
# 8            KNN_turb_0     Turbina        0  0.887182      0.916532
# 9     GaussianNB_turb_0     Turbina        0  0.366657      0.282820
# 10           SVC_turb_0     Turbina        0  0.330075      0.762561
# 11      AdaBoost_turb_0     Turbina        0  0.629154      0.795786
# 12  DecisionTree_comp_1  Compressor        1  0.956716      0.879350
# 13  RandomForest_comp_1  Compressor        1  0.971237      0.902552
# 14           KNN_comp_1  Compressor        1  0.958112      0.832947
# 15    GaussianNB_comp_1  Compressor        1  0.788886      0.000000
# 16           SVC_comp_1  Compressor        1  0.788886      0.000000
# 17      AdaBoost_comp_1  Compressor        1  0.866238      0.417633
# 18  DecisionTree_turb_1     Turbina        1  0.950852      0.880299
# 19  RandomForest_turb_1     Turbina        1  0.965652      0.880299
# 20           KNN_turb_1     Turbina        1  0.933817      0.788030
# 21    GaussianNB_turb_1     Turbina        1  0.775202      0.009975
# 22           SVC_turb_1     Turbina        1  0.774085      0.000000
# 23      AdaBoost_turb_1     Turbina        1  0.822954      0.334165
# 24  DecisionTree_comp_2  Compressor        2  0.957275      0.759259
# 25  RandomForest_comp_2  Compressor        2  0.963418      0.791667
# 26           KNN_comp_2  Compressor        2  0.960905      0.745370
# 27    GaussianNB_comp_2  Compressor        2  0.878246      0.000000
# 28           SVC_comp_2  Compressor        2  0.878246      0.000000
# 29      AdaBoost_comp_2  Compressor        2  0.882156      0.060185
# 30  DecisionTree_turb_2     Turbina        2  0.944987      0.726277
# 31  RandomForest_turb_2     Turbina        2  0.963697      0.843066
# 32           KNN_turb_2     Turbina        2  0.949455      0.770073
# 33    GaussianNB_turb_2     Turbina        2  0.883552      0.000000
# 34           SVC_turb_2     Turbina        2  0.883552      0.000000
# 35      AdaBoost_turb_2     Turbina        2  0.891092      0.102190
#
#     F1-score_Emerg
# 0         0.967742
# 1         0.970923
# 2         0.945111
# 3         0.321205
# 4         0.389916
# 5         0.722143
# 6         0.957300
# 7         0.980979
# 8         0.908434
# 9         0.329401
# 10        0.466766
# 11        0.738068
# 12        0.900238
# 13        0.921801
# 14        0.873479
# 15        0.000000
# 16        0.000000
# 17        0.534918
# 18        0.893671
# 19        0.916883
# 20        0.842667
# 21        0.019560
# 22        0.000000
# 23        0.447412
# 24        0.803922
# 25        0.840295
# 26        0.791155
# 27        0.000000
# 28        0.000000
# 29        0.110638
# 30        0.755218
# 31        0.860335
# 32        0.782931
# 33        0.000000
# 34        0.000000
# 35        0.179487

# %% [markdown]
# ## 5 - Avaliação dos Resultados (Evaluation)

# %% [markdown]
# As métricas utilizadas para avaliação do modelo serão a acurácia total a revocação (recall) da classe 'Emerg'. Isto porque a primeira mede o índice geral de acerto do modelo e a segunda mede o quanto o modelo é sensível para detectar o caso mais crítico, que é quando a manutenção tem que ser executada de maneira emergencial. Um balanço entre as duas é desejável, uma vez que de nada adiantaria um recall de 100% com um modelo que atribuísse 100% das saídas ao status 'Emerg' e estivesse errado em todos os demais casos.
#
# ![recall](img/recall.png)

# %% [markdown]
# ### Cenário 0:

# %%
# Resultados para o compressor
resultados[(resultados['Cenario']==0) & (resultados['Estagio']=='Compressor')].sort_values(by='Acuracia', ascending=False)
# Out:
#                 Modelo     Estagio  Cenario  Acuracia  Recall_Emerg  \
# 1  RandomForest_comp_0  Compressor        0  0.963697      0.971332
# 0  DecisionTree_comp_0  Compressor        0  0.951410      0.973862
# 2           KNN_comp_0  Compressor        0  0.929349      0.929174
# 5      AdaBoost_comp_0  Compressor        0  0.688634      0.636594
# 4           SVC_comp_0  Compressor        0  0.334823      0.489039
# 3    GaussianNB_comp_0  Compressor        0  0.325607      0.323777
#
#    F1-score_Emerg
# 1        0.970923
# 0        0.967742
# 2        0.945111
# 5        0.722143
# 4        0.389916
# 3        0.321205

# %%
# Resultados para a turbina
resultados[(resultados['Cenario']==0) & (resultados['Estagio']=='Turbina')].sort_values(by='Acuracia', ascending=False)
# Out:
#                  Modelo  Estagio  Cenario  Acuracia  Recall_Emerg  \
# 7   RandomForest_turb_0  Turbina        0  0.971796      0.982172
# 6   DecisionTree_turb_0  Turbina        0  0.940519      0.953809
# 8            KNN_turb_0  Turbina        0  0.887182      0.916532
# 11      AdaBoost_turb_0  Turbina        0  0.629154      0.795786
# 9     GaussianNB_turb_0  Turbina        0  0.366657      0.282820
# 10           SVC_turb_0  Turbina        0  0.330075      0.762561
#
#     F1-score_Emerg
# 7         0.980979
# 6         0.957300
# 8         0.908434
# 11        0.738068
# 9         0.329401
# 10        0.466766

# %% [markdown]
# ### Cenário 1:

# %%
# Resultados para o compressor
resultados[(resultados['Cenario']==1) & (resultados['Estagio']=='Compressor')].sort_values(by='Acuracia', ascending=False)
# Out:
#                  Modelo     Estagio  Cenario  Acuracia  Recall_Emerg  \
# 13  RandomForest_comp_1  Compressor        1  0.971237      0.902552
# 14           KNN_comp_1  Compressor        1  0.958112      0.832947
# 12  DecisionTree_comp_1  Compressor        1  0.956716      0.879350
# 17      AdaBoost_comp_1  Compressor        1  0.866238      0.417633
# 15    GaussianNB_comp_1  Compressor        1  0.788886      0.000000
# 16           SVC_comp_1  Compressor        1  0.788886      0.000000
#
#     F1-score_Emerg
# 13        0.921801
# 14        0.873479
# 12        0.900238
# 17        0.534918
# 15        0.000000
# 16        0.000000

# %%
# Resultados para a turbina
resultados[(resultados['Cenario']==1) & (resultados['Estagio']=='Turbina')].sort_values(by='Acuracia', ascending=False)
# Out:
#                  Modelo  Estagio  Cenario  Acuracia  Recall_Emerg  \
# 19  RandomForest_turb_1  Turbina        1  0.965652      0.880299
# 18  DecisionTree_turb_1  Turbina        1  0.950852      0.880299
# 20           KNN_turb_1  Turbina        1  0.933817      0.788030
# 23      AdaBoost_turb_1  Turbina        1  0.822954      0.334165
# 21    GaussianNB_turb_1  Turbina        1  0.775202      0.009975
# 22           SVC_turb_1  Turbina        1  0.774085      0.000000
#
#     F1-score_Emerg
# 19        0.916883
# 18        0.893671
# 20        0.842667
# 23        0.447412
# 21        0.019560
# 22        0.000000

# %% [markdown]
# ### Cenário 2:

# %%
# Resultados para o compressor
resultados[(resultados['Cenario']==2) & (resultados['Estagio']=='Compressor')].sort_values(by='Acuracia', ascending=False)
# Out:
#                  Modelo     Estagio  Cenario  Acuracia  Recall_Emerg  \
# 25  RandomForest_comp_2  Compressor        2  0.963418      0.791667
# 26           KNN_comp_2  Compressor        2  0.960905      0.745370
# 24  DecisionTree_comp_2  Compressor        2  0.957275      0.759259
# 29      AdaBoost_comp_2  Compressor        2  0.882156      0.060185
# 27    GaussianNB_comp_2  Compressor        2  0.878246      0.000000
# 28           SVC_comp_2  Compressor        2  0.878246      0.000000
#
#     F1-score_Emerg
# 25        0.840295
# 26        0.791155
# 24        0.803922
# 29        0.110638
# 27        0.000000
# 28        0.000000

# %%
# Resultados para a turbina
resultados[(resultados['Cenario']==2) & (resultados['Estagio']=='Turbina')].sort_values(by='Acuracia', ascending=False)
# Out:
#                  Modelo  Estagio  Cenario  Acuracia  Recall_Emerg  \
# 31  RandomForest_turb_2  Turbina        2  0.963697      0.843066
# 32           KNN_turb_2  Turbina        2  0.949455      0.770073
# 30  DecisionTree_turb_2  Turbina        2  0.944987      0.726277
# 35      AdaBoost_turb_2  Turbina        2  0.891092      0.102190
# 33    GaussianNB_turb_2  Turbina        2  0.883552      0.000000
# 34           SVC_turb_2  Turbina        2  0.883552      0.000000
#
#     F1-score_Emerg
# 31        0.860335
# 32        0.782931
# 30        0.755218
# 35        0.179487
# 33        0.000000
# 34        0.000000
